# %% [markdown]
# # Classification of trades signs

# %%
# Import modules

from matplotlib import pyplot as plt
import numpy as np
import gzip
import pickle
import multiprocessing
from itertools import product
import datetime

# %matplotlib inline

# %% [markdown]
# ### List of order types:
#
# * "B" = 1 -- Add buy order
# * "S" = 2 -- Add sell order
# * "E" = 3 -- Execute outstanding order in part
# * "C" = 4 -- Cancel outstanding order in part
# * "F" = 5 -- Execute outstanding order in full
# * "D" = 6 -- Delete outstanding order in full
# * "X" = 7 -- Bulk volume for the cross event
# * "T" = 8 -- Execute non-displayed order

# %%
# List of stocks and days

tickers=["AAL", "AAPL","ADBE","ADI", "ADP", "ADSK","AKAM","ALXN","AMAT","AMGN",
         "AMZN","ATVI","AVGO","BBBY","BIDU","BIIB","BMRN","CA",  "CELG","CERN",
        "CHKP","CHRW","CHTR","CMCSA","COST","CSCO","CTSH","CTXS","DISCA","DISH",
         "DLTR","EA",  "EBAY","EQIX","ESRX","EXPD","FAST","FB",  "FISV","FOXA",
         "GILD","GOOG","GRMN","HSIC","ILMN","INTC","INTU","ISRG","JD",  "KHC",
         "KLAC","LBTYA","LLTC","LMCA","LRCX","LVNTA","MAR","MAT","MDLZ","MNST",
         "MSFT","MU",  "MYL", "NFLX","NTAP","NVDA","NXPI","ORLY","PAYX","PCAR",
         "PCLN","QCOM","REGN","ROST","SBAC","SBUX","SIRI","SNDK","SPLS","SRCL",
         "STX", "SYMC","TRIP","TSCO","TSLA","TXN", "VIAB","VIP", "VOD", "VRSK",
         "VRTX","WDC", "WFM", "WYNN","XLNX","YHOO"]

days=['07','08','09','10','11']

# %%
def trade_signs(ticker, day):
    '''
    Obtain the trade signs from the ITCH 2016 data. For further calculations we use the whole time range from the 
    opening of the market at 9h30 to the closing at 16h in milliseconds and then convert the values to hours (23.4
    million data). To fill the time spaces when nothing happens we just fill with
    zeros indicating that there were neither a buy nor a sell. Save in a pickle file the array of the trade signs
    
    ticker -- String of the abbreviation of the stock to be analized (i.e. 'AAPL')
    day -- String of the day to be analized (i.e '07')
    
    return None
    '''
    
# -----------------------------------------------------------------------------------------------------------------------        
    
    print('Trade signs data')
    print('Processing data for the stock', ticker, 'the day', day + ' March, 2016')
    
    # Load data

    data = np.genfromtxt(gzip.open('../../ITCH_2016/201603%s_%s.csv.gz' % (day,ticker)), 
                      dtype='str', skip_header = 1, delimiter = ',')
    
# -----------------------------------------------------------------------------------------------------------------------        

    # Lists of times, ids, types, volumes and prices
    # List of all the available information available in the data excluding the last two columns

    times_ = np.array([int(mytime) for mytime in data[:,0]])
    ids_ = np.array([int(myid) for myid in data[:,2]])             # List of order types: 
    types_ = np.array([1 * (mytype == 'B') +                       # "B" = 1 -> Add buy order
                    2 * (mytype == 'S') +                          # "S" = 2 -> Add sell order
                    3 * (mytype == 'E') +                          # "E" = 3 -> Execute outstanding order in part
                    4 * (mytype == 'C') +                          # "C" = 4 -> Cancel outstanding order in part
                    5 * (mytype == 'F') +                          # "F" = 5 -> Execute outstanding order in full
                    6 * (mytype == 'D') +                          # "D" = 6 -> Delete outstanding order in full
                    7 * (mytype == 'X') +                          # "X" = 7 -> Bulk volume for the cross event
                    8 * (mytype == 'T') for mytype in data[:,3]])  # "T" = 8 -> Execute non-displayed order
    volumes_ = np.array([int(myvolume) for myvolume in data[:,4]])
    prices_ = np.array([int(myprice) for myprice in data[:,5]])

    ids = ids_[types_<7]
    times = times_[types_<7]
    types = types_[types_<7]

# -----------------------------------------------------------------------------------------------------------------------        

    # Reference lists
    # Reference lists using the original values or the length of the original lists 

    types_ref = 0 * types
    times_ref = 0 * times
    index_ref= 0 * types
    newids = {}
    insertnr = {}
    hv = 0

    # Help lists with the data of the buy orders and sell orders

    hv_types = types[types < 3]
    hv_times = times[types < 3]

    trade_sign = 0 * types

# -----------------------------------------------------------------------------------------------------------------------        

    # Fill the reference lists where the values of 'T' are 'E','C','F','D'

    for iii in range(len(ids)):                             # For the data in the length of the ids list (all data)

        if (types[iii] < 3):                                # If the data is a sell or buy order

            newids[ids[iii]] = hv                           # Insert in the dictionary newids a key with the valor of the id
                                                            # and the value of hv (a counter) that is the index in hv_types
            hv += 1                                         # Increase the value of hv

            trade_sign[iii] = 0

        elif (types[iii] == 3 or
                types[iii] == 5):                                            # If the data is not a sell or buy order

            types_ref[iii] = hv_types[newids[ids[iii]]]     # Fill the values of types_ref with no  prices ('E','C','F','D') 
                                                            # with the type of the order
            times_ref[iii] = hv_times[newids[ids[iii]]]     # Fill the values of time_ref with no  prices ('E','C','F','D') 
                                                            # with the time of the order

            if (hv_types[newids[ids[iii]]] == 2):

                trade_sign[iii] = -1

            elif (hv_types[newids[ids[iii]]] == 1):

                trade_sign[iii] = 1

        else:

            types_ref[iii] = hv_types[newids[ids[iii]]]     # Fill the values of types_ref with no  prices ('E','C','F','D') 
                                                            # with the type of the order
            times_ref[iii] = hv_times[newids[ids[iii]]]     # Fill the values of time_ref with no  prices ('E','C','F','D') 
                                                            # with the time of the order

            trade_sign[iii] = 0

# -----------------------------------------------------------------------------------------------------------------------        

    # Ordering the data in the open market time 

    day_times_ind = (1. * times / 3600 / 1000 > 9.5) * (1. * times / 3600 / 1000 < 16) > 0 # This line behaves as an or.
                                                               # The two arrays must achieve a condition, in this case, be
                                                               # in the market trade hours
    trade_signs = trade_sign[day_times_ind]
    times_signs = times[day_times_ind] / 3600 / 1000

# -----------------------------------------------------------------------------------------------------------------------        

    # Saving data
    
    pickle.dump(trade_signs, open('../Data/trade_signs_201603%s_%s.pickl' % (day,ticker), 'wb'))
    pickle.dump(trade_sign, open('../Data/trade_signs_test%s_%s.pickl' % (day,ticker), 'wb'))
    pickle.dump(times, open('../Data/trade_signs_time_test%s_%s.pickl' % (day,ticker), 'wb'))

# %%
trade_signs('AAPL', '07')
# Out:
# Trade signs data
# Processing data for the stock AAPL the day 07 March, 2016

# %%
with multiprocessing.Pool(processes = 8) as pool:
    pool.starmap(trade_signs, product(tickers, days))
    
pool.close()
pool.join()
# Out:
# Processing data for the stock AKAM the day 07 March, 2016
# Processing data for the stock AAL the day 07 March, 2016
# Processing data for the stock BIIB the day 07 March, 2016
# Processing data for the stock CELG the day 07 March, 2016
# Processing data for the stock AMGN the day 07 March, 2016
# Processing data for the stock ADI the day 07 March, 2016
# Processing data for the stock AVGO the day 07 March, 2016
# Processing data for the stock CHRW the day 07 March, 2016
# Processing data for the stock BIIB the day 08 March, 2016
# Processing data for the stock ADI the day 08 March, 2016
# Processing data for the stock CHRW the day 08 March, 2016
# Processing data for the stock AKAM the day 08 March, 2016
# Processing data for the stock AMGN the day 08 March, 2016
# Processing data for the stock CELG the day 08 March, 2016
# Processing data for the stock BIIB the day 09 March, 2016
# Processing data for the stock CHRW the day 09 March, 2016
# Processing data for the stock AVGO the day 08 March, 2016
# Processing data for the stock AAL the day 08 March, 2016
# Processing data for the stock ADI the day 09 March, 2016
# Processing data for the stock BIIB the day 10 March, 2016
# Processing data for the stock AMGN the day 09 March, 2016
# Processing data for the stock CHRW the day 10 March, 2016
# Processing data for the stock AKAM the day 09 March, 2016
# Processing data for the stock BIIB the day 11 March, 2016
# Processing data for the stock CELG the day 09 March, 2016
# Processing data for the stock AVGO the day 09 March, 2016
# Processing data for the stock CHRW the day 11 March, 2016
# Processing data for the stock ADI the day 10 March, 2016
# Processing data for the stock AKAM the day 10 March, 2016
# Processing data for the stock AMGN the day 10 March, 2016
# Processing data for the stock BMRN the day 07 March, 2016
# Processing data for the stock CHTR the day 07 March, 2016
# Processing data for the stock AVGO the day 10 March, 2016
# Processing data for the stock CHTR the day 08 March, 2016
# Processing data for the stock BMRN the day 08 March, 2016
# Processing data for the stock ADI the day 11 March, 2016
# Processing data for the stock AMGN the day 11 March, 2016
# Processing data for the stock AKAM the day 11 March, 2016
# Processing data for the stock AAL the day 09 March, 2016
# Processing data for the stock CHTR the day 09 March, 2016
# Processing data for the stock BMRN the day 09 March, 2016
# Processing data for the stock CELG the day 10 March, 2016
# Processing data for the stock AMZN the day 07 March, 2016
# Processing data for the stock ADP the day 07 March, 2016
# Processing data for the stock AVGO the day 11 March, 2016
# Processing data for the stock CHTR the day 10 March, 2016
# Processing data for the stock ALXN the day 07 March, 2016
# Processing data for the stock BMRN the day 10 March, 2016
# Processing data for the stock ALXN the day 08 March, 2016
# Processing data for the stock AMZN the day 08 March, 2016
# Processing data for the stock CHTR the day 11 March, 2016
# Processing data for the stock BMRN the day 11 March, 2016
# Processing data for the stock ADP the day 08 March, 2016
# Processing data for the stock BBBY the day 07 March, 2016
# Processing data for the stock ALXN the day 09 March, 2016
# Processing data for the stock CELG the day 11 March, 2016
# Processing data for the stock CMCSA the day 07 March, 2016
# Processing data for the stock CA the day 07 March, 2016
# Processing data for the stock AAL the day 10 March, 2016
# Processing data for the stock AMZN the day 09 March, 2016
# Processing data for the stock ALXN the day 10 March, 2016
# Processing data for the stock BBBY the day 08 March, 2016
# Processing data for the stock CA the day 08 March, 2016
# Processing data for the stock ADP the day 09 March, 2016
# Processing data for the stock ALXN the day 11 March, 2016
# Processing data for the stock CERN the day 07 March, 2016
# Processing data for the stock CA the day 09 March, 2016
# Processing data for the stock BBBY the day 09 March, 2016
# Processing data for the stock AMAT the day 07 March, 2016
# Processing data for the stock ADP the day 10 March, 2016
# Processing data for the stock AAL the day 11 March, 2016
# Processing data for the stock AMZN the day 10 March, 2016
# Processing data for the stock BBBY the day 10 March, 2016
# Processing data for the stock CA the day 10 March, 2016
# Processing data for the stock CERN the day 08 March, 2016
# Processing data for the stock AMZN the day 11 March, 2016
# Processing data for the stock BBBY the day 11 March, 2016
# Processing data for the stock AMAT the day 08 March, 2016
# Processing data for the stock ADP the day 11 March, 2016
# Processing data for the stock CA the day 11 March, 2016
# Processing data for the stock AAPL the day 07 March, 2016
# Processing data for the stock CERN the day 09 March, 2016
# Processing data for the stock CMCSA the day 08 March, 2016
# Processing data for the stock ATVI the day 07 March, 2016
# Processing data for the stock BIDU the day 07 March, 2016
# Processing data for the stock COST the day 07 March, 2016
# Processing data for the stock AMAT the day 09 March, 2016
# Processing data for the stock ADSK the day 07 March, 2016
# Processing data for the stock BIDU the day 08 March, 2016
# Processing data for the stock COST the day 08 March, 2016
# Processing data for the stock BIDU the day 09 March, 2016
# Processing data for the stock CERN the day 10 March, 2016
# Processing data for the stock ADSK the day 08 March, 2016
# Processing data for the stock BIDU the day 10 March, 2016
# Processing data for the stock AMAT the day 10 March, 2016
# Processing data for the stock COST the day 09 March, 2016
# Processing data for the stock BIDU the day 11 March, 2016
# Processing data for the stock ATVI the day 08 March, 2016
# Processing data for the stock CERN the day 11 March, 2016
# Processing data for the stock CTXS the day 07 March, 2016
# Processing data for the stock ADSK the day 09 March, 2016
# Processing data for the stock COST the day 10 March, 2016
# Processing data for the stock CHKP the day 07 March, 2016
# Processing data for the stock CTXS the day 08 March, 2016
# Processing data for the stock COST the day 11 March, 2016
# Processing data for the stock CMCSA the day 09 March, 2016
# Processing data for the stock CHKP the day 08 March, 2016
# Processing data for the stock ADSK the day 10 March, 2016
# Processing data for the stock CTXS the day 09 March, 2016
# Processing data for the stock CSCO the day 07 March, 2016
# Processing data for the stock AMAT the day 11 March, 2016
# Processing data for the stock CHKP the day 09 March, 2016
# Processing data for the stock ATVI the day 09 March, 2016
# Processing data for the stock CHKP the day 10 March, 2016
# Processing data for the stock CTXS the day 10 March, 2016
# Processing data for the stock ADSK the day 11 March, 2016
# Processing data for the stock CHKP the day 11 March, 2016
# Processing data for the stock DLTR the day 07 March, 2016
# Processing data for the stock AAPL the day 08 March, 2016
# Processing data for the stock CTXS the day 11 March, 2016
# Processing data for the stock EQIX the day 07 March, 2016
# Processing data for the stock FAST the day 07 March, 2016
# Processing data for the stock CSCO the day 08 March, 2016
# Processing data for the stock DISCA the day 07 March, 2016
# Processing data for the stock EQIX the day 08 March, 2016
# Processing data for the stock DLTR the day 08 March, 2016
# Processing data for the stock FAST the day 08 March, 2016
# Processing data for the stock ATVI the day 10 March, 2016
# Processing data for the stock EQIX the day 09 March, 2016
# Processing data for the stock CMCSA the day 10 March, 2016
# Processing data for the stock DLTR the day 09 March, 2016
# Processing data for the stock FAST the day 09 March, 2016
# Processing data for the stock EQIX the day 10 March, 2016
# Processing data for the stock DISCA the day 08 March, 2016
# Processing data for the stock EQIX the day 11 March, 2016
# Processing data for the stock CSCO the day 09 March, 2016
# Processing data for the stock DLTR the day 10 March, 2016
# Processing data for the stock FAST the day 10 March, 2016
# Processing data for the stock ESRX the day 07 March, 2016
# Processing data for the stock DLTR the day 11 March, 2016
# Processing data for the stock ATVI the day 11 March, 2016
# Processing data for the stock FAST the day 11 March, 2016
# Processing data for the stock DISCA the day 09 March, 2016
# Processing data for the stock ESRX the day 08 March, 2016
# Processing data for the stock EA the day 07 March, 2016
# Processing data for the stock FB the day 07 March, 2016
# Processing data for the stock CSCO the day 10 March, 2016
# Processing data for the stock FOXA the day 07 March, 2016
# Processing data for the stock DISCA the day 10 March, 2016
# Processing data for the stock EA the day 08 March, 2016
# Processing data for the stock ESRX the day 09 March, 2016
# Processing data for the stock AAPL the day 09 March, 2016
# Processing data for the stock FOXA the day 08 March, 2016
# Processing data for the stock CMCSA the day 11 March, 2016
# Processing data for the stock EA the day 09 March, 2016
# Processing data for the stock ESRX the day 10 March, 2016
# Processing data for the stock DISCA the day 11 March, 2016
# Processing data for the stock CSCO the day 11 March, 2016
# Processing data for the stock EA the day 10 March, 2016
# Processing data for the stock FOXA the day 09 March, 2016
# Processing data for the stock FB the day 08 March, 2016
# Processing data for the stock ESRX the day 11 March, 2016
# Processing data for the stock DISH the day 07 March, 2016
# Processing data for the stock EA the day 11 March, 2016
# Processing data for the stock GRMN the day 07 March, 2016
# Processing data for the stock DISH the day 08 March, 2016
# Processing data for the stock FOXA the day 10 March, 2016
# Processing data for the stock GRMN the day 08 March, 2016
# Processing data for the stock EXPD the day 07 March, 2016
# Processing data for the stock CTSH the day 07 March, 2016
# Processing data for the stock DISH the day 09 March, 2016
# Processing data for the stock GRMN the day 09 March, 2016
# Processing data for the stock EBAY the day 07 March, 2016
# Processing data for the stock EXPD the day 08 March, 2016
# Processing data for the stock DISH the day 10 March, 2016
# Processing data for the stock CTSH the day 08 March, 2016
# Processing data for the stock EXPD the day 09 March, 2016
# Processing data for the stock GRMN the day 10 March, 2016
# Processing data for the stock FOXA the day 11 March, 2016
# Processing data for the stock DISH the day 11 March, 2016
# Processing data for the stock EBAY the day 08 March, 2016
# Processing data for the stock GRMN the day 11 March, 2016
# Processing data for the stock INTC the day 07 March, 2016
# Processing data for the stock EXPD the day 10 March, 2016
# Processing data for the stock AAPL the day 10 March, 2016
# Processing data for the stock CTSH the day 09 March, 2016
# Processing data for the stock HSIC the day 07 March, 2016
# Processing data for the stock HSIC the day 08 March, 2016
# Processing data for the stock GILD the day 07 March, 2016
# Processing data for the stock EXPD the day 11 March, 2016
# Processing data for the stock HSIC the day 09 March, 2016
# Processing data for the stock FB the day 09 March, 2016
# Processing data for the stock HSIC the day 10 March, 2016
# Processing data for the stock CTSH the day 10 March, 2016
# Processing data for the stock HSIC the day 11 March, 2016
# Processing data for the stock JD the day 07 March, 2016
# Processing data for the stock EBAY the day 09 March, 2016
# Processing data for the stock ILMN the day 07 March, 2016
# Processing data for the stock ILMN the day 08 March, 2016
# Processing data for the stock INTC the day 08 March, 2016
# Processing data for the stock ILMN the day 09 March, 2016
# Processing data for the stock CTSH the day 11 March, 2016
# Processing data for the stock ILMN the day 10 March, 2016
# Processing data for the stock GILD the day 08 March, 2016
# Processing data for the stock JD the day 08 March, 2016
# Processing data for the stock EBAY the day 10 March, 2016
# Processing data for the stock ILMN the day 11 March, 2016
# Processing data for the stock LBTYA the day 07 March, 2016
# Processing data for the stock LRCX the day 07 March, 2016
# Processing data for the stock JD the day 09 March, 2016
# Processing data for the stock INTC the day 09 March, 2016
# Processing data for the stock LRCX the day 08 March, 2016
# Processing data for the stock FB the day 10 March, 2016
# Processing data for the stock LBTYA the day 08 March, 2016
# Processing data for the stock GILD the day 09 March, 2016
# Processing data for the stock EBAY the day 11 March, 2016
# Processing data for the stock JD the day 10 March, 2016
# Processing data for the stock LRCX the day 09 March, 2016
# Processing data for the stock MAT the day 07 March, 2016
# Processing data for the stock LBTYA the day 09 March, 2016
# Processing data for the stock LRCX the day 10 March, 2016
# Processing data for the stock INTC the day 10 March, 2016
# Processing data for the stock GILD the day 10 March, 2016
# Processing data for the stock MAT the day 08 March, 2016
# Processing data for the stock LRCX the day 11 March, 2016
# Processing data for the stock JD the day 11 March, 2016
# Processing data for the stock LBTYA the day 10 March, 2016
# Processing data for the stock AAPL the day 11 March, 2016
# Processing data for the stock MAT the day 09 March, 2016
# Processing data for the stock LVNTA the day 07 March, 2016
# Processing data for the stock LVNTA the day 08 March, 2016
# Processing data for the stock KHC the day 07 March, 2016
# Processing data for the stock LVNTA the day 09 March, 2016
# Processing data for the stock LVNTA the day 10 March, 2016
# Processing data for the stock LBTYA the day 11 March, 2016
# Processing data for the stock GILD the day 11 March, 2016
# Processing data for the stock LVNTA the day 11 March, 2016
# Processing data for the stock MAT the day 10 March, 2016
# Processing data for the stock MAR the day 07 March, 2016
# Processing data for the stock KHC the day 08 March, 2016
# Processing data for the stock INTC the day 11 March, 2016
# Processing data for the stock FB the day 11 March, 2016
# Processing data for the stock LLTC the day 07 March, 2016
# Processing data for the stock MAR the day 08 March, 2016
# Processing data for the stock MAT the day 11 March, 2016
# Processing data for the stock KHC the day 09 March, 2016
# Processing data for the stock GOOG the day 07 March, 2016
# Processing data for the stock MDLZ the day 07 March, 2016
# Processing data for the stock MAR the day 09 March, 2016
# Processing data for the stock KHC the day 10 March, 2016
# Processing data for the stock LLTC the day 08 March, 2016
# Processing data for the stock INTU the day 07 March, 2016
# Processing data for the stock KHC the day 11 March, 2016
# Processing data for the stock INTU the day 08 March, 2016
# Processing data for the stock LLTC the day 09 March, 2016
# Processing data for the stock MAR the day 10 March, 2016
# Processing data for the stock GOOG the day 08 March, 2016
# Processing data for the stock ADBE the day 07 March, 2016
# Processing data for the stock MDLZ the day 08 March, 2016
# Processing data for the stock FISV the day 07 March, 2016
# Processing data for the stock KLAC the day 07 March, 2016
# Processing data for the stock INTU the day 09 March, 2016
# Processing data for the stock LLTC the day 10 March, 2016
# Processing data for the stock FISV the day 08 March, 2016
# Processing data for the stock MAR the day 11 March, 2016
# Processing data for the stock ADBE the day 08 March, 2016
# Processing data for the stock INTU the day 10 March, 2016
# Processing data for the stock KLAC the day 08 March, 2016
# Processing data for the stock FISV the day 09 March, 2016
# Processing data for the stock MDLZ the day 09 March, 2016
# Processing data for the stock GOOG the day 09 March, 2016
# Processing data for the stock INTU the day 11 March, 2016
# Processing data for the stock FISV the day 10 March, 2016
# Processing data for the stock LLTC the day 11 March, 2016
# Processing data for the stock MSFT the day 07 March, 2016
# Processing data for the stock KLAC the day 09 March, 2016
# Processing data for the stock ADBE the day 09 March, 2016
# Processing data for the stock FISV the day 11 March, 2016
# Processing data for the stock ISRG the day 07 March, 2016
# Processing data for the stock ISRG the day 08 March, 2016
# Processing data for the stock ISRG the day 09 March, 2016
# Processing data for the stock LMCA the day 07 March, 2016
# Processing data for the stock KLAC the day 10 March, 2016
# Processing data for the stock NFLX the day 07 March, 2016
# Processing data for the stock MDLZ the day 10 March, 2016
# Processing data for the stock ISRG the day 10 March, 2016
# Processing data for the stock ADBE the day 10 March, 2016
# Processing data for the stock ISRG the day 11 March, 2016
# Processing data for the stock GOOG the day 10 March, 2016
# Processing data for the stock NXPI the day 07 March, 2016
# Processing data for the stock LMCA the day 08 March, 2016
# Processing data for the stock KLAC the day 11 March, 2016
# Processing data for the stock NXPI the day 08 March, 2016
# Processing data for the stock LMCA the day 09 March, 2016
# Processing data for the stock ADBE the day 11 March, 2016
# Processing data for the stock PCAR the day 07 March, 2016
# Processing data for the stock MDLZ the day 11 March, 2016
# Processing data for the stock LMCA the day 10 March, 2016
# Processing data for the stock NFLX the day 08 March, 2016
# Processing data for the stock GOOG the day 11 March, 2016
# Processing data for the stock REGN the day 07 March, 2016
# Processing data for the stock NXPI the day 09 March, 2016
# Processing data for the stock REGN the day 08 March, 2016
# Processing data for the stock PCAR the day 08 March, 2016
# Processing data for the stock LMCA the day 11 March, 2016
# Processing data for the stock REGN the day 09 March, 2016
# Processing data for the stock MSFT the day 08 March, 2016
# Processing data for the stock SBUX the day 07 March, 2016
# Processing data for the stock REGN the day 10 March, 2016
# Processing data for the stock NXPI the day 10 March, 2016
# Processing data for the stock MNST the day 07 March, 2016
# Processing data for the stock SPLS the day 07 March, 2016
# Processing data for the stock REGN the day 11 March, 2016
# Processing data for the stock PCAR the day 09 March, 2016
# Processing data for the stock MNST the day 08 March, 2016
# Processing data for the stock ROST the day 07 March, 2016
# Processing data for the stock SPLS the day 08 March, 2016
# Processing data for the stock MNST the day 09 March, 2016
# Processing data for the stock NFLX the day 09 March, 2016
# Processing data for the stock NXPI the day 11 March, 2016
# Processing data for the stock PCAR the day 10 March, 2016
# Processing data for the stock MNST the day 10 March, 2016
# Processing data for the stock MNST the day 11 March, 2016
# Processing data for the stock SPLS the day 09 March, 2016
# Processing data for the stock SBUX the day 08 March, 2016
# Processing data for the stock ROST the day 08 March, 2016
# Processing data for the stock ORLY the day 07 March, 2016
# Processing data for the stock SYMC the day 07 March, 2016
# Processing data for the stock PCAR the day 11 March, 2016
# Processing data for the stock ORLY the day 08 March, 2016
# Processing data for the stock SPLS the day 10 March, 2016
# Processing data for the stock ORLY the day 09 March, 2016
# Processing data for the stock SYMC the day 08 March, 2016
# Processing data for the stock NFLX the day 10 March, 2016
# Processing data for the stock PCLN the day 07 March, 2016
# Processing data for the stock ORLY the day 10 March, 2016
# Processing data for the stock SPLS the day 11 March, 2016
# Processing data for the stock ROST the day 09 March, 2016
# Processing data for the stock PCLN the day 08 March, 2016
# Processing data for the stock MSFT the day 09 March, 2016
# Processing data for the stock PCLN the day 09 March, 2016
# Processing data for the stock SYMC the day 09 March, 2016
# Processing data for the stock ORLY the day 11 March, 2016
# Processing data for the stock SRCL the day 07 March, 2016
# Processing data for the stock PAYX the day 07 March, 2016
# Processing data for the stock SBUX the day 09 March, 2016
# Processing data for the stock SRCL the day 08 March, 2016
# Processing data for the stock PCLN the day 10 March, 2016
# Processing data for the stock ROST the day 10 March, 2016
# Processing data for the stock SRCL the day 09 March, 2016
# Processing data for the stock SYMC the day 10 March, 2016
# Processing data for the stock PCLN the day 11 March, 2016
# Processing data for the stock SRCL the day 10 March, 2016
# Processing data for the stock QCOM the day 07 March, 2016
# Processing data for the stock NFLX the day 11 March, 2016
# Processing data for the stock PAYX the day 08 March, 2016
# Processing data for the stock SRCL the day 11 March, 2016
# Processing data for the stock STX the day 07 March, 2016
# Processing data for the stock SYMC the day 11 March, 2016
# Processing data for the stock ROST the day 11 March, 2016
# Processing data for the stock PAYX the day 09 March, 2016
# Processing data for the stock TRIP the day 07 March, 2016
# Processing data for the stock SBUX the day 10 March, 2016
# Processing data for the stock STX the day 08 March, 2016
# Processing data for the stock NTAP the day 07 March, 2016
# Processing data for the stock PAYX the day 10 March, 2016
# Processing data for the stock SBAC the day 07 March, 2016
# Processing data for the stock TRIP the day 08 March, 2016
# Processing data for the stock MSFT the day 10 March, 2016
# Processing data for the stock QCOM the day 08 March, 2016
# Processing data for the stock SBAC the day 08 March, 2016
# Processing data for the stock PAYX the day 11 March, 2016
# Processing data for the stock NTAP the day 08 March, 2016
# Processing data for the stock STX the day 09 March, 2016
# Processing data for the stock TRIP the day 09 March, 2016
# Processing data for the stock SBAC the day 09 March, 2016
# Processing data for the stock TSLA the day 07 March, 2016
# Processing data for the stock TRIP the day 10 March, 2016
# Processing data for the stock SBAC the day 10 March, 2016
# Processing data for the stock STX the day 10 March, 2016
# Processing data for the stock NTAP the day 09 March, 2016
# Processing data for the stock TSLA the day 08 March, 2016
# Processing data for the stock TRIP the day 11 March, 2016
# Processing data for the stock SBAC the day 11 March, 2016
# Processing data for the stock SBUX the day 11 March, 2016
# Processing data for the stock TSLA the day 09 March, 2016
# Processing data for the stock VIP the day 07 March, 2016
# Processing data for the stock TSCO the day 07 March, 2016
# Processing data for the stock VIP the day 08 March, 2016
# Processing data for the stock NTAP the day 10 March, 2016
# Processing data for the stock VIP the day 09 March, 2016
# Processing data for the stock TSLA the day 10 March, 2016
# Processing data for the stock VIP the day 10 March, 2016
# Processing data for the stock STX the day 11 March, 2016
# Processing data for the stock QCOM the day 09 March, 2016
# Processing data for the stock TSCO the day 08 March, 2016
# Processing data for the stock VIP the day 11 March, 2016
# Processing data for the stock VOD the day 07 March, 2016
# Processing data for the stock TSLA the day 11 March, 2016
# Processing data for the stock TSCO the day 09 March, 2016
# Processing data for the stock TSCO the day 10 March, 2016
# Processing data for the stock TXN the day 07 March, 2016
# Processing data for the stock VRTX the day 07 March, 2016
# Processing data for the stock NTAP the day 11 March, 2016
# Processing data for the stock SIRI the day 07 March, 2016
# Processing data for the stock TSCO the day 11 March, 2016
# Processing data for the stock VRTX the day 08 March, 2016
# Processing data for the stock WYNN the day 07 March, 2016
# Processing data for the stock VOD the day 08 March, 2016
# Processing data for the stock VRTX the day 09 March, 2016
# Processing data for the stock NVDA the day 07 March, 2016
# Processing data for the stock QCOM the day 10 March, 2016
# Processing data for the stock TXN the day 08 March, 2016
# Processing data for the stock VRTX the day 10 March, 2016
# Processing data for the stock WYNN the day 08 March, 2016
# Processing data for the stock SIRI the day 08 March, 2016
# Processing data for the stock VRTX the day 11 March, 2016
# Processing data for the stock NVDA the day 08 March, 2016
# Processing data for the stock WDC the day 07 March, 2016
# Processing data for the stock VOD the day 09 March, 2016
# Processing data for the stock WYNN the day 09 March, 2016
# Processing data for the stock MSFT the day 11 March, 2016
# Processing data for the stock TXN the day 09 March, 2016
# Processing data for the stock WYNN the day 10 March, 2016
# Processing data for the stock NVDA the day 09 March, 2016
# Processing data for the stock QCOM the day 11 March, 2016
# Processing data for the stock WDC the day 08 March, 2016
# Processing data for the stock WYNN the day 11 March, 2016
# Processing data for the stock VOD the day 10 March, 2016
# Processing data for the stock TXN the day 10 March, 2016
# Processing data for the stock XLNX the day 07 March, 2016
# Processing data for the stock WDC the day 09 March, 2016
# Processing data for the stock NVDA the day 10 March, 2016
# Processing data for the stock XLNX the day 08 March, 2016
# Processing data for the stock WDC the day 10 March, 2016
# Processing data for the stock MU the day 07 March, 2016
# Processing data for the stock TXN the day 11 March, 2016
# Processing data for the stock XLNX the day 09 March, 2016
# Processing data for the stock VOD the day 11 March, 2016
# Processing data for the stock XLNX the day 10 March, 2016
# Processing data for the stock NVDA the day 11 March, 2016
# Processing data for the stock SIRI the day 09 March, 2016
# Processing data for the stock WDC the day 11 March, 2016
# Processing data for the stock VIAB the day 07 March, 2016
# Processing data for the stock MU the day 08 March, 2016
# Processing data for the stock XLNX the day 11 March, 2016
# Processing data for the stock VRSK the day 07 March, 2016
# Processing data for the stock VRSK the day 08 March, 2016
# Processing data for the stock WFM the day 07 March, 2016
# Processing data for the stock VIAB the day 08 March, 2016
# Processing data for the stock YHOO the day 07 March, 2016
# Processing data for the stock VRSK the day 09 March, 2016
# Processing data for the stock MU the day 09 March, 2016
# Processing data for the stock VRSK the day 10 March, 2016
# Processing data for the stock VRSK the day 11 March, 2016
# Processing data for the stock VIAB the day 09 March, 2016
# Processing data for the stock MU the day 10 March, 2016
# Processing data for the stock VIAB the day 10 March, 2016
# Processing data for the stock WFM the day 08 March, 2016
# Processing data for the stock VIAB the day 11 March, 2016
# Processing data for the stock MU the day 11 March, 2016
# Processing data for the stock WFM the day 09 March, 2016
# Processing data for the stock SIRI the day 10 March, 2016
# Processing data for the stock MYL the day 07 March, 2016
# Processing data for the stock WFM the day 10 March, 2016
# Processing data for the stock YHOO the day 08 March, 2016
# Processing data for the stock SIRI the day 11 March, 2016
# Processing data for the stock MYL the day 08 March, 2016
# Processing data for the stock WFM the day 11 March, 2016
# Processing data for the stock SNDK the day 07 March, 2016
# Processing data for the stock SNDK the day 08 March, 2016
# Processing data for the stock MYL the day 09 March, 2016
# Processing data for the stock SNDK the day 09 March, 2016
# Processing data for the stock YHOO the day 09 March, 2016
# Processing data for the stock SNDK the day 10 March, 2016
# Processing data for the stock MYL the day 10 March, 2016
# Processing data for the stock SNDK the day 11 March, 2016
# Processing data for the stock MYL the day 11 March, 2016
# Processing data for the stock YHOO the day 10 March, 2016
# Processing data for the stock YHOO the day 11 March, 2016
