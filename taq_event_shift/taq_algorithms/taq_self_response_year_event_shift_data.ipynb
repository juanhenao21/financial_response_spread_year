# %% [markdown]
# # taq_self_response_year_event_shift_data
#
# #### Juan Camilo Henao Londono - 08.07.2019
# #### AG Guhr - Universitaet Duisburg-Essen
#
# In the following [link]() can be seen the plot of the function's results

# %%
# Modules

import numpy as np
import os

import pickle

import taq_data_tools
import taq_data_analysis

# %%
def taq_self_response_year_event_shift_data(ticker, year, tau):
    """
    Obtain the year average self response function using the midpoint
    price returns and trade signs of the ticker during different time
    lags. Return an array with the year average self response.
        :param ticker: string of the abbreviation of the midpoint stock to
         be analized (i.e. 'AAPL')
        :param year: string of the year to be analized (i.e '2016')
    """

    function_name = taq_self_response_year_event_shift_data.__name__
    taq_data_tools.taq_function_header_print_data(function_name, ticker,
                                                  ticker, year, '', '')

    dates = taq_data_tools.taq_bussiness_days(year)

    shift_val = range(- 10 * tau, 10 * tau, 1)
    self_ = np.zeros(len(shift_val))
    num_s = []

    for date in dates:

        try:

            data, avg_num = taq_self_response_day_event_shift_data(ticker, date,
                                                                   tau)

            self_ += data

            num_s.append(avg_num)

        except TypeError:
            pass

    num_s = np.asarray(num_s)
    num_s_t = np.sum(num_s, axis=0)

    # Saving data
    taq_data_tools.taq_save_data('{}_tau_{}'.format(function_name, tau),
                                 self_ / num_s_t, ticker, ticker,
                                 year, '', '')

    return self_ / num_s_t, num_s_t

# %%
# Test

tickers = ['AAPL', 'MSFT']
year = '2008'
taus = [1, 10, 100, 1000]

for ticker in tickers:
    for tau in taus:
        taq_self_response_year_event_shift_data(ticker, year, tau)
# Out:
# TAQ data
# taq_self_response_year_time_shift_data
# Processing data for the stock AAPL the 2008..
# TAQ data
# taq_self_response_day_time_shift_data
# Processing data for the stock AAPL the 2008.01.01
# No data
#
# TAQ data
# taq_self_response_day_time_shift_data
# Processing data for the stock AAPL the 2008.01.02
# TAQ data
# taq_self_response_day_time_shift_data
# Processing data for the stock AAPL the 2008.01.03
# TAQ data
# taq_self_response_day_time_shift_data
# Processing data for the stock AAPL the 2008.01.04
# TAQ data
# taq_self_response_day_time_shift_data
# Processing data for the stock AAPL the 2008.01.07
# TAQ data
# taq_self_response_day_time_shift_data
# Processing data for the stock AAPL the 2008.01.08
# TAQ data
# taq_self_response_day_time_shift_data
# Processing data for the stock AAPL the 2008.01.09
# TAQ data
# taq_self_response_day_time_shift_data
# Processing data for the stock AAPL the 2008.01.10
# TAQ data
# taq_self_response_day_time_shift_data
# Processing data for the stock AAPL the 2008.01.11
# TAQ data
# taq_self_response_day_time_shift_data
# Processing data for the stock AAPL the 2008.01.14
# TAQ data
# taq_self_response_day_time_shift_data
# Processing data for the stock AAPL the 2008.01.15
# TAQ data
# taq_self_response_day_time_shift_data
# Processing data for the stock AAPL the 2008.01.16
# TAQ data
# taq_self_response_day_time_shift_data
# Processing data for the stock AAPL the 2008.01.17
# TAQ data
# taq_self_response_day_time_shift_data
# Processing data for the stock AAPL the 2008.01.18
# TAQ data
# taq_self_response_day_time_shift_data
# Processing data for the stock AAPL the 2008.01.21
# No data
#
# TAQ data
# taq_self_response_day_time_shift_data
# Processing data for the stock AAPL the 2008.01.22
# TAQ data
# taq_self_response_day_time_shift_data
# Processing data for the stock AAPL the 2008.01.23
# TAQ data
# taq_self_response_day_time_shift_data
# Processing data for the stock AAPL the 2008.01.24
# TAQ data
# taq_self_response_day_time_shift_data
# Processing data for the stock AAPL the 2008.01.25
# TAQ data
# taq_self_response_day_time_shift_data
# Processing data for the stock AAPL the 2008.01.28
# TAQ data
# taq_self_response_day_time_shift_data
# Processing data for the stock AAPL the 2008.01.29
# TAQ data
# taq_self_response_day_time_shift_data
# Processing data for the stock AAPL the 2008.01.30
# TAQ data
# taq_self_response_day_time_shift_data
# Processing data for the stock AAPL the 2008.01.31
# TAQ data
# taq_self_response_day_time_shift_data
# Processing data for the stock AAPL the 2008.02.01
# TAQ data
# taq_self_response_day_time_shift_data
# Processing data for the stock AAPL the 2008.02.04
# TAQ data
# taq_self_response_day_time_shift_data
# Processing data for the stock AAPL the 2008.02.05
# TAQ data
# taq_self_response_day_time_shift_data
# Processing data for the stock AAPL the 2008.02.06
# TAQ data
# taq_self_response_day_time_shift_data
# Processing data for the stock AAPL the 2008.02.07
# TAQ data
# taq_self_response_day_time_shift_data
# Processing data for the stock AAPL the 2008.02.08
# TAQ data
# taq_self_response_day_time_shift_data
# Processing data for the stock AAPL the 2008.02.11
# TAQ data
# taq_self_response_day_time_shift_data
# Processing data for the stock AAPL the 2008.02.12
# TAQ data
# taq_self_response_day_time_shift_data
# Processing data for the stock AAPL the 2008.02.13
# TAQ data
# taq_self_response_day_time_shift_data
# Processing data for the stock AAPL the 2008.02.14
# TAQ data
# taq_self_response_day_time_shift_data
# Processing data for the stock AAPL the 2008.02.15
# TAQ data
# taq_self_response_day_time_shift_data
# Processing data for the stock AAPL the 2008.02.18
# No data
#
# TAQ data
# taq_self_response_day_time_shift_data
# Processing data for the stock AAPL the 2008.02.19
# TAQ data
# taq_self_response_day_time_shift_data
# Processing data for the stock AAPL the 2008.02.20
# TAQ data
# taq_self_response_day_time_shift_data
# Processing data for the stock AAPL the 2008.02.21
# TAQ data
# taq_self_response_day_time_shift_data
# Processing data for the stock AAPL the 2008.02.22
# TAQ data
# taq_self_response_day_time_shift_data
# Processing data for the stock AAPL the 2008.02.25
# TAQ data
# taq_self_response_day_time_shift_data
# Processing data for the stock AAPL the 2008.02.26
# TAQ data
# taq_self_response_day_time_shift_data
# Processing data for the stock AAPL the 2008.02.27
# TAQ data
# taq_self_response_day_time_shift_data
# Processing data for the stock AAPL the 2008.02.28
# TAQ data
# taq_self_response_day_time_shift_data
# Processing data for the stock AAPL the 2008.02.29
# TAQ data
# taq_self_response_day_time_shift_data
# Processing data for the stock AAPL the 2008.03.03
# TAQ data
# taq_self_response_day_time_shift_data
# Processing data for the stock AAPL the 2008.03.04
# TAQ data
# taq_self_response_day_time_shift_data
# Processing data for the stock AAPL the 2008.03.05
# TAQ data
# taq_self_response_day_time_shift_data
# Processing data for the stock AAPL the 2008.03.06
# TAQ data
# taq_self_response_day_time_shift_data
# Processing data for the stock AAPL the 2008.03.07
# TAQ data
# taq_self_response_day_time_shift_data
# Processing data for the stock AAPL the 2008.03.10
# TAQ data
# taq_self_response_day_time_shift_data
# Processing data for the stock AAPL the 2008.03.11
# TAQ data
# taq_self_response_day_time_shift_data
# Processing data for the stock AAPL the 2008.03.12
# TAQ data
# taq_self_response_day_time_shift_data
# Processing data for the stock AAPL the 2008.03.13
# TAQ data
# taq_self_response_day_time_shift_data
# Processing data for the stock AAPL the 2008.03.14
# TAQ data
# taq_self_response_day_time_shift_data
# Processing data for the stock AAPL the 2008.03.17
# TAQ data
# taq_self_response_day_time_shift_data
# Processing data for the stock AAPL the 2008.03.18
# TAQ data
# taq_self_response_day_time_shift_data
# Processing data for the stock AAPL the 2008.03.19
# TAQ data
# taq_self_response_day_time_shift_data
# Processing data for the stock AAPL the 2008.03.20
# TAQ data
# taq_self_response_day_time_shift_data
# Processing data for the stock AAPL the 2008.03.21
# No data
#
# TAQ data
# taq_self_response_day_time_shift_data
# Processing data for the stock AAPL the 2008.03.24
# TAQ data
# taq_self_response_day_time_shift_data
# Processing data for the stock AAPL the 2008.03.25
# TAQ data
# taq_self_response_day_time_shift_data
# Processing data for the stock AAPL the 2008.03.26
# TAQ data
# taq_self_response_day_time_shift_data
# Processing data for the stock AAPL the 2008.03.27
# TAQ data
# taq_self_response_day_time_shift_data
# Processing data for the stock AAPL the 2008.03.28
# TAQ data
# taq_self_response_day_time_shift_data
# Processing data for the stock AAPL the 2008.03.31
# TAQ data
# taq_self_response_day_time_shift_data
# Processing data for the stock AAPL the 2008.04.01
# TAQ data
# taq_self_response_day_time_shift_data
# Processing data for the stock AAPL the 2008.04.02
# TAQ data
# taq_self_response_day_time_shift_data
# Processing data for the stock AAPL the 2008.04.03
# TAQ data
# taq_self_response_day_time_shift_data
# Processing data for the stock AAPL the 2008.04.04
# TAQ data
# taq_self_response_day_time_shift_data
# Processing data for the stock AAPL the 2008.04.07
# TAQ data
# taq_self_response_day_time_shift_data
# Processing data for the stock AAPL the 2008.04.08
# TAQ data
# taq_self_response_day_time_shift_data
# Processing data for the stock AAPL the 2008.04.09
# TAQ data
# taq_self_response_day_time_shift_data
# Processing data for the stock AAPL the 2008.04.10
# TAQ data
# taq_self_response_day_time_shift_data
# Processing data for the stock AAPL the 2008.04.11
# TAQ data
# taq_self_response_day_time_shift_data
# Processing data for the stock AAPL the 2008.04.14
# TAQ data
# taq_self_response_day_time_shift_data
# Processing data for the stock AAPL the 2008.04.15
# TAQ data
# taq_self_response_day_time_shift_data
# Processing data for the stock AAPL the 2008.04.16
# TAQ data
# taq_self_response_day_time_shift_data
# Processing data for the stock AAPL the 2008.04.17
# TAQ data
# taq_self_response_day_time_shift_data
# Processing data for the stock AAPL the 2008.04.18
# TAQ data
# taq_self_response_day_time_shift_data
# Processing data for the stock AAPL the 2008.04.21
# TAQ data
# taq_self_response_day_time_shift_data
# Processing data for the stock AAPL the 2008.04.22
# TAQ data
# taq_self_response_day_time_shift_data
# Processing data for the stock AAPL the 2008.04.23
# TAQ data
# taq_self_response_day_time_shift_data
# Processing data for the stock AAPL the 2008.04.24
# TAQ data
# taq_self_response_day_time_shift_data
# Processing data for the stock AAPL the 2008.04.25
# TAQ data
# taq_self_response_day_time_shift_data
# Processing data for the stock AAPL the 2008.04.28
# TAQ data
# taq_self_response_day_time_shift_data
# Processing data for the stock AAPL the 2008.04.29
# TAQ data
# taq_self_response_day_time_shift_data
# Processing data for the stock AAPL the 2008.04.30
# TAQ data
# taq_self_response_day_time_shift_data
# Processing data for the stock AAPL the 2008.05.01
# TAQ data
# taq_self_response_day_time_shift_data
# Processing data for the stock AAPL the 2008.05.02
# TAQ data
# taq_self_response_day_time_shift_data
# Processing data for the stock AAPL the 2008.05.05
# TAQ data
# taq_self_response_day_time_shift_data
# Processing data for the stock AAPL the 2008.05.06
# TAQ data
# taq_self_response_day_time_shift_data
# Processing data for the stock AAPL the 2008.05.07
# TAQ data
# taq_self_response_day_time_shift_data
# Processing data for the stock AAPL the 2008.05.08
# TAQ data
# taq_self_response_day_time_shift_data
# Processing data for the stock AAPL the 2008.05.09
# TAQ data
# taq_self_response_day_time_shift_data
# Processing data for the stock AAPL the 2008.05.12
# TAQ data
# taq_self_response_day_time_shift_data
# Processing data for the stock AAPL the 2008.05.13
# TAQ data
# taq_self_response_day_time_shift_data
# Processing data for the stock AAPL the 2008.05.14
# TAQ data
# taq_self_response_day_time_shift_data
# Processing data for the stock AAPL the 2008.05.15
# TAQ data
# taq_self_response_day_time_shift_data
# Processing data for the stock AAPL the 2008.05.16
# TAQ data
# taq_self_response_day_time_shift_data
# Processing data for the stock AAPL the 2008.05.19
# TAQ data
# taq_self_response_day_time_shift_data
# Processing data for the stock AAPL the 2008.05.20
# TAQ data
# taq_self_response_day_time_shift_data
# Processing data for the stock AAPL the 2008.05.21
# TAQ data
# taq_self_response_day_time_shift_data
# Processing data for the stock AAPL the 2008.05.22
# TAQ data
# taq_self_response_day_time_shift_data
# Processing data for the stock AAPL the 2008.05.23
# TAQ data
# taq_self_response_day_time_shift_data
# Processing data for the stock AAPL the 2008.05.26
# No data
#
# TAQ data
# taq_self_response_day_time_shift_data
# Processing data for the stock AAPL the 2008.05.27
# TAQ data
# taq_self_response_day_time_shift_data
# Processing data for the stock AAPL the 2008.05.28
# TAQ data
# taq_self_response_day_time_shift_data
# Processing data for the stock AAPL the 2008.05.29
# TAQ data
# taq_self_response_day_time_shift_data
# Processing data for the stock AAPL the 2008.05.30
# TAQ data
# taq_self_response_day_time_shift_data
# Processing data for the stock AAPL the 2008.06.02
# TAQ data
# taq_self_response_day_time_shift_data
# Processing data for the stock AAPL the 2008.06.03
# TAQ data
# taq_self_response_day_time_shift_data
# Processing data for the stock AAPL the 2008.06.04
# TAQ data
# taq_self_response_day_time_shift_data
# Processing data for the stock AAPL the 2008.06.05
# TAQ data
# taq_self_response_day_time_shift_data
# Processing data for the stock AAPL the 2008.06.06
# TAQ data
# taq_self_response_day_time_shift_data
# Processing data for the stock AAPL the 2008.06.09
# TAQ data
# taq_self_response_day_time_shift_data
# Processing data for the stock AAPL the 2008.06.10
# TAQ data
# taq_self_response_day_time_shift_data
# Processing data for the stock AAPL the 2008.06.11
# TAQ data
# taq_self_response_day_time_shift_data
# Processing data for the stock AAPL the 2008.06.12
# TAQ data
# taq_self_response_day_time_shift_data
# Processing data for the stock AAPL the 2008.06.13
# TAQ data
# taq_self_response_day_time_shift_data
# Processing data for the stock AAPL the 2008.06.16
# TAQ data
# taq_self_response_day_time_shift_data
# Processing data for the stock AAPL the 2008.06.17
# TAQ data
# taq_self_response_day_time_shift_data
# Processing data for the stock AAPL the 2008.06.18
# TAQ data
# taq_self_response_day_time_shift_data
# Processing data for the stock AAPL the 2008.06.19
# TAQ data
# taq_self_response_day_time_shift_data
# Processing data for the stock AAPL the 2008.06.20
# TAQ data
# taq_self_response_day_time_shift_data
# Processing data for the stock AAPL the 2008.06.23
# TAQ data
# taq_self_response_day_time_shift_data
# Processing data for the stock AAPL the 2008.06.24
# TAQ data
# taq_self_response_day_time_shift_data
# Processing data for the stock AAPL the 2008.06.25
# TAQ data
# taq_self_response_day_time_shift_data
# Processing data for the stock AAPL the 2008.06.26
# TAQ data
# taq_self_response_day_time_shift_data
# Processing data for the stock AAPL the 2008.06.27
# TAQ data
# taq_self_response_day_time_shift_data
# Processing data for the stock AAPL the 2008.06.30
# TAQ data
# taq_self_response_day_time_shift_data
# Processing data for the stock AAPL the 2008.07.01
# TAQ data
# taq_self_response_day_time_shift_data
# Processing data for the stock AAPL the 2008.07.02
# TAQ data
# taq_self_response_day_time_shift_data
# Processing data for the stock AAPL the 2008.07.03
# TAQ data
# taq_self_response_day_time_shift_data
# Processing data for the stock AAPL the 2008.07.04
# No data
#
# TAQ data
# taq_self_response_day_time_shift_data
# Processing data for the stock AAPL the 2008.07.07
# TAQ data
# taq_self_response_day_time_shift_data
# Processing data for the stock AAPL the 2008.07.08
# TAQ data
# taq_self_response_day_time_shift_data
# Processing data for the stock AAPL the 2008