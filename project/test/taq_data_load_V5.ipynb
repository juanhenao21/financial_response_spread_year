# %% [markdown]
# # taq_data_extract
#
# #### Juan Camilo Henao Londono - 26.03.2019
# #### AG Guhr - Universitaet Duisburg-Essen
#
# Time test between my load method and Droopy's method.

# %%
# Modules
import pandas as pd
import numpy as np

# %%
def taq_data_extract_juan(ticker, year, month, day):
    """
    Extract the trades and quotes (TAQ) data for a day, from a CSV file with
    the full information of a year. The time range for each day is from 9:40
    to 15:50 (including both).
        :param ticker: string of the abbreviation of the stock to be analized
                       (i.e. 'AAPL')
        :param year: string of the year to be analized (i.e '2008')
        :param month: string of the month to be analized (i.e '07')
        :param day: string of the day to be analized (i.e '07')
    """

    # Load data
    date = '{}-{}-{}'.format(year, month, day)
    quotes_filename = '../TAQ_{1}/Data/{0}_{1}_NASDAQ.quotes' \
                      .format(ticker, year)
    trades_filename = '../TAQ_{1}/Data/{0}_{1}_NASDAQ.trades' \
                      .format(ticker, year)
    quotes_day_list = []
    trades_day_list = []

    with open(quotes_filename, 'rb') as f_quotes:
        for idx, line in enumerate(f_quotes):
            print(chardet.detect(line))
            list_line = line.split()
            if (list_line[0] == date
                    and list_line[1] >= '34800'
                    and list_line[1] <= '57000'):
                quotes_day_list.append(list_line[:4])

    assert len(quotes_day_list) != 0

    with open(trades_filename, 'rb') as f_trades:
        for idx, line in enumerate(f_trades):
            list_line = line.split()
            if (list_line[0] == date
                    and list_line[1] >= '34800'
                    and list_line[1] <= '57000'):
                trades_day_list.append(list_line[:3])

    assert len(trades_day_list) != 0

    quotes_df = pd.DataFrame(quotes_day_list,
                             columns=['Date', 'Time', 'Bid', 'Ask'])
    trades_df = pd.DataFrame(trades_day_list,
                             columns=['Date', 'Time', 'Ask'])

    return (quotes_df, trades_df)

# %%
def taq_data_extract_droopy(ticker, year, month, day, chunksize):
    """
    Extract the trades and quotes (TAQ) data for a day, from a CSV file with
    the full information of a year. The time range for each day is from 9:40
    to 15:50 (including both).
        :param ticker: string of the abbreviation of the stock to be analized
                       (i.e. 'AAPL')
        :param year: string of the year to be analized (i.e '2008')
        :param month: string of the month to be analized (i.e '07')
        :param day: string of the day to be analized (i.e '07')
    """

    # Load data
    date = '{}-{}-{}'.format(year, month, day)
    quotes_filename = '../TAQ_{1}/Data/{0}_{1}_NASDAQ.quotes' \
                      .format(ticker, year)
    trades_filename = '../TAQ_{1}/Data/{0}_{1}_NASDAQ.trades' \
                      .format(ticker, year)
    
    quotes_df = pd.DataFrame()
    trades_df = pd.DataFrame()
    
    for chunk in pd.read_csv(quotes_filename, chunksize=chunksize, sep="\s+",
                             names = ['Date', 'Time', 'Bid', 'Ask'], usecols=range(4)
                        ):
    
        copy = chunk.loc[(chunk['Date'] == date) & (chunk['Time'] >= 34800)
                         & (chunk['Time'] <= 57000)]
        quotes_df = quotes_df.append(copy)
        
    for chunk in pd.read_csv(trades_filename, chunksize=chunksize, sep="\s+",
                             names = ['Date', 'Time', 'Ask'], usecols=range(3)
                        ):
    
        copy = chunk.loc[(chunk['Date'] == date) & (chunk['Time'] >= 34800)
                         & (chunk['Time'] <= 57000)]
        trades_df = trades_df.append(copy)

    return (quotes_df, trades_df)

# %%
ticker = 'AAPL'
year = '2008'
month = '01'
day = '02'
chunksize = 1000000

# %%
# %%time
x, y = taq_data_extract_juan(ticker, year, month, day)
# Out:
# {'encoding': None, 'confidence': 0.0, 'language': None}
# {'encoding': None, 'confidence': 0.0, 'language': None}
# {'encoding': None, 'confidence': 0.0, 'language': None}
# {'encoding': None, 'confidence': 0.0, 'language': None}
# {'encoding': None, 'confidence': 0.0, 'language': None}
# {'encoding': None, 'confidence': 0.0, 'language': None}
# {'encoding': None, 'confidence': 0.0, 'language': None}
# {'encoding': 'KOI8-R', 'confidence': 0.4388398420352105, 'language': 'Russian'}
# {'encoding': None, 'confidence': 0.0, 'language': None}
# {'encoding': 'ISO-8859-1', 'confidence': 0.73, 'language': ''}
# {'encoding': None, 'confidence': 0.0, 'language': None}
# {'encoding': None, 'confidence': 0.0, 'language': None}
# {'encoding': None, 'confidence': 0.0, 'language': None}
# {'encoding': None, 'confidence': 0.0, 'language': None}
# {'encoding': None, 'confidence': 0.0, 'language': None}
# {'encoding': None, 'confidence': 0.0, 'language': None}
# {'encoding': None, 'confidence': 0.0, 'language': None}
# {'encoding': 'ISO-8859-1', 'confidence': 0.73, 'language': ''}
# {'encoding': None, 'confidence': 0.0, 'language': None}
# {'encoding': None, 'confidence': 0.0, 'language': None}
# {'encoding': None, 'confidence': 0.0, 'language': None}
# {'encoding': None, 'confidence': 0.0, 'language': None}
# {'encoding': None, 'confidence': 0.0, 'language': None}
# {'encoding': None, 'confidence': 0.0, 'language': None}
# {'encoding': 'IBM855', 'confidence': 0.20294695397424145, 'language': 'Russian'}
# {'encoding': None, 'confidence': 0.0, 'language': None}
# {'encoding': None, 'confidence': 0.0, 'language': None}
# {'encoding': None, 'confidence': 0.0, 'language': None}
# {'encoding': None, 'confidence': 0.0, 'language': None}
# {'encoding': 'Windows-1253', 'confidence': 0.7630861646373661, 'language': 'Greek'}
# {'encoding': 'ISO-8859-1', 'confidence': 0.73, 'language': ''}
# {'encoding': None, 'confidence': 0.0, 'language': None}
# {'encoding': None, 'confidence': 0.0, 'language': None}
# {'encoding': 'ISO-8859-1', 'confidence': 0.73, 'language': ''}
# {'encoding': None, 'confidence': 0.0, 'language': None}
# {'encoding': None, 'confidence': 0.0, 'language': None}
# {'encoding': None, 'confidence': 0.0, 'language': None}
# {'encoding': 'Windows-1252', 'confidence': 0.31, 'language': ''}
# {'encoding': None, 'confidence': 0.0, 'language': None}
# {'encoding': None, 'confidence': 0.0, 'language': None}
# {'encoding': None, 'confidence': 0.0, 'language': None}
# {'encoding': None, 'confidence': 0.0, 'language': None}
# {'encoding': None, 'confidence': 0.0, 'language': None}
# {'encoding': None, 'confidence': 0.0, 'language': None}
# {'encoding': 'Windows-1252', 'confidence': 0.73, 'language': ''}
# {'encoding': None, 'confidence': 0.0, 'language': None}
# {'encoding': None, 'confidence': 0.0, 'language': None}
# {'encoding': None, 'confidence': 0.0, 'language': None}
# {'encoding': None, 'confidence': 0.0, 'language': None}
# {'encoding': None, 'confidence': 0.0, 'language': None}
# {'encoding': None, 'confidence': 0.0, 'language': None}
# {'encoding': None, 'confidence': 0.0, 'language': None}
# {'encoding': None, 'confidence': 0.0, 'language': None}
# {'encoding': None, 'confidence': 0.0, 'language': None}
# {'encoding': 'Windows-1251', 'confidence': 0.41262977206331386, 'language': 'Bulgairan'}
# {'encoding': 'Windows-1252', 'confidence': 0.73, 'language': ''}
# {'encoding': None, 'confidence': 0.0, 'language': None}
# {'encoding': 'Windows-1252', 'confidence': 0.73, 'language': ''}
# {'encoding': None, 'confidence': 0.0, 'language': None}
# {'encoding': None, 'confidence': 0.0, 'language': None}
# {'encoding': None, 'confidence': 0.0, 'language': None}
# {'encoding': None, 'confidence': 0.0, 'language': None}
# {'encoding': None, 'confidence': 0.0, 'language': None}
# {'encoding': None, 'confidence': 0.0, 'language': None}
# {'encoding': None, 'confidence': 0.0, 'language': None}
# {'encoding': None, 'confidence': 0.0, 'language': None}
# {'encoding': 'TIS-620', 'confidence': 0.2302855757031446, 'language': 'Thai'}
# {'encoding': None, 'confidence': 0.0, 'language': None}
# {'encoding': None, 'confidence': 0.0, 'language': None}
# {'encoding': None, 'confidence': 0.0, 'language': None}
# {'encoding': None, 'confidence': 0.0, 'language': None}
# {'encoding': None, 'confidence': 0.0, 'language': None}
# {'encoding': None, 'confidence': 0.0, 'language': None}
# {'encoding': None, 'confidence': 0.0, 'language': None}
# {'encoding': None, 'confidence': 0.0, 'language': None}
# {'encoding': None, 'confidence': 0.0, 'language': None}
# {'encoding': 'ISO-8859-1', 'confidence': 0.73, 'language': ''}
# {'encoding': None, 'confidence': 0.0, 'language': None}
# {'encoding': 'windows-1255', 'confidence': 0.2018590747459374, 'language': 'Hebrew'}
# {'encoding': None, 'confidence': 0.0, 'language': None}
# {'encoding': None, 'confidence': 0.0, 'language': None}
# {'encoding': 'Windows-1252', 'confidence': 0.73, 'language': ''}
# {'encoding': None, 'confidence': 0.0, 'language': None}
# {'encoding': None, 'confidence': 0.0, 'language': None}
# {'encoding': None, 'confidence': 0.0, 'language': None}
# {'encoding': None, 'confidence': 0.0, 'language': None}
# {'encoding': None, 'confidence': 0.0, 'language': None}
# {'encoding': None, 'confidence': 0.0, 'language': None}
# {'encoding': 'Windows-1252', 'confidence': 0.7144680851063829, 'language': ''}
# {'encoding': None, 'confidence': 0.0, 'language': None}
# {'encoding': None, 'confidence': 0.0, 'language': None}
# {'encoding': 'Windows-1251', 'confidence': 0.4835505141366959, 'language': 'Bulgairan'}
# {'encoding': None, 'confidence': 0.0, 'language': None}
# {'encoding': None, 'confidence': 0.0, 'language': None}
# {'encoding': None, 'confidence': 0.0, 'language': None}
# {'encoding': None, 'confidence': 0.0, 'language': None}
# {'encoding': None, 'confidence': 0.0, 'language': None}
# {'encoding': None, 'confidence': 0.0, 'language': None}
# {'encoding': None, 'confidence': 0.0, 'language': None}
# {'encoding': None, 'confidence': 0.0, 'language': None}
# {'encoding': None, 'confidence': 0.0, 'language': None}
# {'encoding': None, 'confidence': 0.0, 'language': None}
# {'encoding': None, 'confidence': 0.0, 'language': None}
# {'encoding': None, 'confidence': 0.0, 'language': None}
# {'encoding': None, 'confidence': 0.0, 'language': None}
# {'encoding': None, 'confidence': 0.0, 'language': None}
# {'encoding': None, 'confidence': 0.0, 'language': None}
# {'encoding': None, 'confidence': 0.0, 'language': None}
# {'encoding': None, 'confidence': 0.0, 'language': None}
# {'encoding': 'Windows-1251', 'confidence': 0.24070070037026645, 'language': 'Bulgairan'}
# {'encoding': None, 'confidence': 0.0, 'language': None}
# {'encoding': 'Windows-1252', 'confidence': 0.73, 'language': ''}
# {'encoding': 'TIS-620', 'confidence': 0.47976161604821793, 'language': 'Thai'}
# {'encoding': None, 'confidence': 0.0, 'language': None}
# {'encoding': None, 'confidence': 0.0, 'language': None}
# {'encoding': 'windows-1253', 'confidence': 0.3324994181426432, 'language': 'Greek'}
# {'encoding': None, 'confidence': 0.0, 'language': None}
# {'encoding': None, 'confidence': 0.0, 'language': None}
# {'encoding': None, 'confidence': 0.0, 'language': None}
# {'encoding': None, 'confidence': 0.0, 'language': None}
# {'encoding': None, 'confidence': 0.0, 'language': None}
# {'encoding': None, 'confidence': 0.0, 'language': None}
# {'encoding': None, 'confidence': 0.0, 'language': None}
# {'encoding': None, 'confidence': 0.0, 'language': None}
# {'encoding': 'Windows-1252', 'confidence': 0.73, 'language': ''}
# {'encoding': None, 'confidence': 0.0, 'language': None}
# {'encoding': None, 'confidence': 0.0, 'language': None}
# {'encoding': None, 'confidence': 0.0, 'language': None}
# {'encoding': None, 'confidence': 0.0, 'language': None}
# {'encoding': None, 'confidence': 0.0, 'language': None}
# {'encoding': None, 'confidence': 0.0, 'language': None}
# {'encoding': None, 'confidence': 0.0, 'language': None}
# {'encoding': None, 'confidence': 0.0, 'language': None}
# {'encoding': None, 'confidence': 0.0, 'language': None}
# {'encoding': 'Windows-1252', 'confidence': 0.73, 'language': ''}
# {'encoding': None, 'confidence': 0.0, 'language': None}
# {'encoding': 'windows-1253', 'confidence': 0.34974782545879285, 'language': 'Greek'}
# {'encoding': None, 'confidence': 0.0, 'language': None}
# {'encoding': None, 'confidence': 0.0, 'language': None}
# {'encoding': None, 'confidence': 0.0, 'language': None}
# {'encoding': None, 'confidence': 0.0, 'language': None}
# {'encoding': 'Windows-1254', 'confidence': 0.3235666536520968, 'language': 'Turkish'}
# {'encoding': None, 'confidence': 0.0, 'language': None}
# {'encoding': None, 'confidence': 0.0, 'language': None}
# {'encoding': None, 'confidence': 0.0, 'language': None}
# {'encoding': 'Windows-1253', 'confidence': 0.34757547871681277, 'language': 'Greek'}
# {'encoding': None, 'confidence': 0.0, 'language': None}
# {'encoding': None, 'confidence': 0.0, 'language': None}
# {'encoding': None, 'confidence': 0.0, 'language': None}
# {'encoding': None, 'confidence': 0.0, 'language': None}
# {'encoding': None, 'confidence': 0.0, 'language': None}
# {'encoding': None, 'confidence': 0.0, 'language': None}
# {'encoding': None, 'confidence': 0.0, 'language': None}
# {'encoding': None, 'confidence': 0.0, 'language': None}
# {'encoding': None, 'confidence': 0.0, 'language': None}
# {'encoding': None, 'confidence': 0.0, 'language': None}
# {'encoding': None, 'confidence': 0.0, 'language': None}
# {'encoding': None, 'confidence': 0.0, 'language': None}
# {'encoding': None, 'confidence': 0.0, 'language': None}
# {'encoding': None, 'confidence': 0.0, 'language': None}
# {'encoding': None, 'confidence': 0.0, 'language': None}
# {'encoding': 'KOI8-R', 'confidence': 0.42664984642312126, 'language': 'Russian'}
# {'encoding': None, 'confidence': 0.0, 'language': None}
# {'encoding': None, 'confidence': 0.0, 'language': None}
# {'encoding': None, 'confidence': 0.0, 'language': None}
# {'encoding': None, 'confidence': 0.0, 'language': None}
# {'encoding': None, 'confidence': 0.0, 'language': None}
# {'encoding': None, 'confidence': 0.0, 'language': None}
# {'encoding': None, 'confidence': 0.0, 'language': None}
# {'encoding': None, 'confidence': 0.0, 'language': None}
# {'encoding': None, 'confidence': 0.0, 'language': None}
# {'encoding': None, 'confidence': 0.0, 'language': None}
# {'encoding': None, 'confidence': 0.0, 'language': None}
# {'encoding': None, 'confidence': 0.0, 'language': None}
# {'encoding': None, 'confidence': 0.0, 'language': None}
# {'encoding': None, 'confidence': 0.0, 'language': None}
# {'encoding': None, 'confidence': 0.0, 'language': None}
# {'encoding': None, 'confidence': 0.0, 'language': None}
# {'encoding': None, 'confidence': 0.0, 'language': None}
# {'encoding': None, 'confidence': 0.0, 'language': None}
# {'encoding': None, 'confidence': 0.0, 'language': None}
# {'encoding': None, 'confidence': 0.0, 'language': None}
# {'encoding': None, 'confidence': 0.0, 'language': None}
# {'encoding': None, 'confidence': 0.0, 'language': None}
# {'encoding': None, 'confidence': 0.0, 'language': None}
# {'encoding': None, 'confidence': 0.0, 'language': None}
# {'encoding': None, 'confidence': 0.0, 'language': None}
# {'encoding': None, 'confidence': 0.0, 'language': None}
# {'encoding': None, 'confidence': 0.0, 'language': None}
# {'encoding': None, 'confidence': 0.0, 'language': None}
# {'encoding': None, 'confidence': 0.0, 'language': None}
# {'encoding': None, 'confidence': 0.0, 'language': None}
# {'encoding': None, 'confidence': 0.0, 'language': None}
# {'encoding': None, 'confidence': 0.0, 'language': None}
# {'encoding': None, 'confidence': 0.0, 'language': None}
# {'encoding': None, 'confidence': 0.0, 'language': None}
# {'encoding': None, 'confidence': 0.0, 'language': None}
# {'encoding': None, 'confidence': 0.0, 'language': None}
# {'encoding': None, 'confidence': 0.0, 'language': None}
# {'encoding': None, 'confidence': 0.0, 'language': None}
# {'encoding': None, 'confidence': 0.0, 'language': None}
# {'encoding': None, 'confidence': 0.0, 'language': None}
# {'encoding': None, 'confidence': 0.0, 'language': None}
# {'encoding': None, 'confidence': 0.0, 'language': None}
# {'encoding': None, 'confidence': 0.0, 'language': None}
# {'encoding': None, 'confidence': 0.0, 'language': None}
# {'encoding': None, 'confidence': 0.0, 'language': None}
# {'encoding': None, 'confidence': 0.0, 'language': None}
# {'encoding': 'Windows-1253', 'confidence': 0.2670801576230782, 'language': 'Greek'}
# {'encoding': None, 'confidence': 0.0, 'language': None}
# {'encoding': None, 'confidence': 0.0, 'language': None}
# {'encoding': None, 'confidence': 0.0, 'language': None}
# {'encoding': 'Windows-1254', 'confidence': 0.22902660258502328, 'language': 'Turkish'}
# {'encoding': None, 'confidence': 0.0, 'language': None}
# {'encoding': None, 'confidence': 0.0, 'language': None}
# {'encoding': None, 'confidence': 0.0, 'language': None}
# {'encoding': None, 'confidence': 0.0, 'language': None}
# {'encoding': None, 'confidence': 0.0, 'language': None}
# {'encoding': None, 'confidence': 0.0, 'language': None}
# {'encoding': None, 'confidence': 0.0, 'language': None}
# {'encoding': 'ISO-8859-1', 'confidence': 0.73, 'language': ''}
# {'encoding': None, 'confidence': 0.0, 'language': None}
# {'encoding': None, 'confidence': 0.0, 'language': None}
# {'encoding': None, 'confidence': 0.0, 'language': None}
# {'encoding': None, 'confidence': 0.0, 'language': None}
# {'encoding': None, 'confidence': 0.0, 'language': None}
# {'encoding': None, 'confidence': 0.0, 'language': None}
# {'encoding': None, 'confidence': 0.0, 'language': None}
# {'encoding': None, 'confidence': 0.0, 'language': None}
# {'encoding': None, 'confidence': 0.0, 'language': None}
# {'encoding': None, 'confidence': 0.0, 'language': None}
# {'encoding': None, 'confidence': 0.0, 'language': None}
# {'encoding': None, 'confidence': 0.0, 'language': None}
# {'encoding': None, 'confidence': 0.0, 'language': None}
# {'encoding': None, 'confidence': 0.0, 'language': None}
# {'encoding': None, 'confidence': 0.0, 'language': None}
# {'encoding': None, 'confidence': 0.0, 'language': None}
# {'encoding': None, 'confidence': 0.0, 'language': None}
# {'encoding': None, 'confidence': 0.0, 'language': None}
# {'encoding': None, 'confidence': 0.0, 'language': None}
# {'encoding': None, 'confidence': 0.0, 'language': None}
# {'encoding': None, 'confidence': 0.0, 'language': None}
# {'encoding': None, 'confidence': 0.0, 'language': None}
# {'encoding': None, 'confidence': 0.0, 'language': None}
# {'encoding': None, 'confidence': 0.0, 'language': None}
# {'encoding': None, 'confidence': 0.0, 'language': None}
# {'encoding': None, 'confidence': 0.0, 'language': None}
# {'encoding': None, 'confidence': 0.0, 'language': None}
# {'encoding': None, 'confidence': 0.0, 'language': None}
# {'encoding': None, 'confidence': 0.0, 'language': None}
# {'encoding': None, 'confidence': 0.0, 'language': None}
# {'encoding': None, 'confidence': 0.0, 'language': None}
# {'encoding': None, 'confidence': 0.0, 'language': None}
# {'encoding': None, 'confidence': 0.0, 'language': None}
# {'encoding': None, 'confidence': 0.0, 'language': None}
# {'encoding': None, 'confidence': 0.0, 'language': None}
# {'encoding': None, 'confidence': 0.0, 'language': None}
# {'encoding': None, 'confidence': 0.0, 'language': None}
# {'encoding': None, 'confidence': 0.0, 'language': None}
# {'encoding': None, 'confidence': 0.0, 'language': None}
# {'encoding': None, 'confidence': 0.0, 'language': None}
# {'encoding': None, 'confidence': 0.0, 'language': None}
# {'encoding': None, 'confidence': 0.0, 'language': None}
# {'encoding': None, 'confidence': 0.0, 'language': None}
# {'encoding': None, 'confidence': 0.0, 'language': None}
# {'encoding': None, 'confidence': 0.0, 'language': None}
# {'encoding': None, 'confidence': 0.0, 'language': None}
# {'encoding': None, 'confidence': 0.0, 'language': None}
# {'encoding': None, 'confidence': 0.0, 'language': None}
# {'encoding': None, 'confidence': 0.0, 'language': None}
# {'encoding': None, 'confidence': 0.0, 'language': None}
# {'encoding': None, 'confidence': 0.0, 'language': None}
# {'encoding': None, 'confidence': 0.0, 'language': None}
# {'encoding': None, 'confidence': 0.0, 'language': None}
# {'encoding': None, 'confidence': 0.0, 'language': None}
# {'encoding': None, 'confidence': 0.0, 'language': None}
# {'encoding': None, 'confidence': 0.0, 'language': None}
# {'encoding': None, 'confidence': 0.0, 'language': None}
# {'encoding': None, 'confidence': 0.0, 'language': None}
# {'encoding': None, 'confidence': 0.0, 'language': None}
# {'encoding': None, 'confidence': 0.0, 'language': None}
# {'encoding': None, 'confidence': 0.0, 'language': None}
# {'encoding': None, 'confidence': 0.0, 'language': None}
# {'encoding': None, 'confidence': 0.0, 'language': None}
# {'encoding': None, 'confidence': 0.0, 'language': None}
# {'encoding': None, 'confidence': 0.0, 'language': None}
# {'encoding': 'IBM855', 'confidence': 0.2972786026690135, 'language': 'Russian'}
# {'encoding': None, 'confidence': 0.0, 'language': None}
# {'encoding': None, 'confidence': 0.0, 'language': None}
# {'encoding': None, 'confidence': 0.0, 'language': None}
# {'encoding': None, 'confidence': 0.0, 'language': None}
# {'encoding': None, 'confidence': 0.0, 'language': None}
# {'encoding': None, 'confidence': 0.0, 'language': None}
# {'encoding': None, 'confidence': 0.0, 'language': None}
# {'encoding': None, 'confidence': 0.0, 'language': None}
# {'encoding': None, 'confidence': 0.0, 'language': None}
# {'encoding': None, 'confidence': 0.0, 'language': None}
# {'encoding': None, 'confidence': 0.0, 'language': None}
# {'encoding': None, 'confidence': 0.0, 'language': None}
# {'encoding': None, 'confidence': 0.0, 'language': None}
# {'encoding': None, 'confidence': 0.0, 'language': None}
# {'encoding': None, 'confidence': 0.0, 'language': None}
# {'encoding': None, 'confidence': 0.0, 'language': None}
# {'encoding': None, 'confidence': 0.0, 'language': None}
# {'encoding': None, 'confidence': 0.0, 'language': None}
# {'encoding': None, 'confidence': 0.0, 'language': None}
# {'encoding': None, 'confidence': 0.0, 'language': None}
# {'encoding': None, 'confidence': 0.0, 'language': None}
# {'encoding': None, 'confidence': 0.0, 'language': None}
# {'encoding': None, 'confidence': 0.0, 'language': None}
# {'encoding': None, 'confidence': 0.0, 'language': None}
# {'encoding': None, 'confidence': 0.0, 'language': None}
# {'encoding': None, 'confidence': 0.0, 'language': None}
# {'encoding': None, 'confidence': 0.0, 'language': None}
# {'encoding': None, 'confidence': 0.0, 'language': None}
# {'encoding': None, 'confidence': 0.0, 'language': None}
# {'encoding': None, 'confidence': 0.0, 'language': None}
# {'encoding': None, 'confidence': 0.0, 'language': None}
# {'encoding': None, 'confidence': 0.0, 'language': None}
# {'encoding': None, 'confidence': 0.0, 'language': None}
# {'encoding': None, 'confidence': 0.0, 'language': None}
# {'encoding': None, 'confidence': 0.0, 'language': None}
# {'encoding': None, 'confidence': 0.0, 'language': None}
# {'encoding': 'Windows-1252', 'confidence': 0.73, 'language': ''}
# {'encoding': None, 'confidence': 0.0, 'language': None}
# {'encoding': None, 'confidence': 0.0, 'language': None}
# {'encoding': None, 'confidence': 0.0, 'language': None}
# {'encoding': None, 'confidence': 0.0, 'language': None}
# {'encoding': None, 'confidence': 0.0, 'language': None}
# {'encoding': None, 'confidence': 0.0, 'language': None}
# {'encoding': None, 'confidence': 0.0, 'language': None}
# {'encoding': 'Windows-1253', 'confidence': 0.3058784204242607, 'language': 'Greek'}
# {'encoding': None, 'confidence': 0.0, 'language': None}
# {'encoding': None, 'confidence': 0.0, 'language': None}
# {'encoding': None, 'confidence': 0.0, 'language': None}
# {'encoding': None, 'confidence': 0.0, 'language': None}
# {'encoding': None, 'confidence': 0.0, 'language': None}
# {'encoding': None, 'confidence': 0.0, 'language': None}
# {'encoding': None, 'confidence': 0.0, 'language': None}
# {'encoding': 'windows-1253', 'confidence': 0.2513695601158383, 'language': 'Greek'}
# {'encoding': None, 'confidence': 0.0, 'language': None}
# {'encoding': None, 'confidence': 0.0, 'language': None}
# {'encoding': None, 'confidence': 0.0, 'language': None}
# {'encoding': 'windows-1253', 'confidence': 0.21802461846781887, 'language': 'Greek'}
# {'encoding': 'IBM866', 'confidence': 0.99, 'language': 'Russian'}
# {'encoding': None, 'confidence': 0.0, 'language': None}
# {'encoding': None, 'confidence': 0.0, 'language': None}
# {'encoding': None, 'confidence': 0.0, 'language': None}
# {'encoding': None, 'confidence': 0.0, 'language': None}
# {'encoding': None, 'confidence': 0.0, 'language': None}
# {'encoding': None, 'confidence': 0.0, 'language': None}
# {'encoding': None, 'confidence': 0.0, 'language': None}
# {'encoding': None, 'confidence': 0.0, 'language': None}
# {'encoding': None, 'confidence': 0.0, 'language': None}
# {'encoding': None, 'confidence': 0.0, 'language': None}
# {'encoding': None, 'confidence': 0.0, 'language': None}
# {'encoding': None, 'confidence': 0.0, 'language': None}
# {'encoding': None, 'confidence': 0.0, 'language': None}
# {'encoding': None, 'confidence': 0.0, 'language': None}
# {'encoding': None, 'confidence': 0.0, 'language': None}
# {'encoding': None, 'confidence': 0.0, 'language': None}
# {'encoding': None, 'confidence': 0.0, 'language': None}
# {'encoding': 'KOI8-R', 'confidence': 0.3839848617808091, 'language': 'Russian'}
# {'encoding': None, 'confidence': 0.0, 'language': None}
# {'encoding': None, 'confidence': 0.0, 'language': None}
# {'encoding': None, 'confidence': 0.0, 'language': None}
# {'encoding': None, 'confidence': 0.0, 'language': None}
# {'encoding': None, 'confidence': 0.0, 'language': None}
# {'encoding': None, 'confidence': 0.0, 'language': None}
# {'encoding': None, 'confidence': 0.0, 'language': None}
# {'encoding': None, 'confidence': 0.0, 'language': None}
# {'encoding': None, 'confidence': 0.0, 'language': None}
# {'encoding': None, 'confidence': 0.0, 'language': None}
# {'encoding': None, 'confidence': 0.0, 'language': None}
# {'encoding': 'KOI8-R', 'confidence': 0.38398486178080915, 'language': 'Russian'}
# {'encoding': None, 'confidence': 0.0, 'language': None}
# {'encoding': 'Windows-1253', 'confidence': 0.4866056702035379, 'language': 'Greek'}
# {'encoding': None, 'confidence': 0.0, 'language': None}
# {'encoding': None, 'confidence': 0.0, 'language': None}
# {'encoding': None, 'confidence': 0.0, 'language': None}
# {'encoding': None, 'confidence': 0.0, 'language': None}
# {'encoding': 'windows-1253', 'confidence': 0.29845147772483654, 'language': 'Greek'}
# {'encoding': None, 'confidence': 0.0, 'language': None}
# {'encoding': None, 'confidence': 0.0, 'language': None}
# {'encoding': None, 'confidence': 0.0, 'language': None}
# {'encoding': None, 'confidence': 0.0, 'language': None}
# {'encoding': None, 'confidence': 0.0, 'language': None}
# {'encoding': None, 'confidence': 0.0, 'language': None}
# {'encoding': None, 'confidence': 0.0, 'language': None}
# {'encoding': None, 'confidence': 0.0, 'language': None}
# {'encoding': None, 'confidence': 0.0, 'language': None}
# {'encoding': None, 'confidence': 0.0, 'language': None}
# {'encoding': None, 'confidence': 0.0, 'language': None}
# {'encoding': None, 'confidence': 0.0, 'language': None}
# {'encoding': None, 'confidence': 0.0, 'language': None}
# {'encoding': None, 'confidence': 0.0, 'language': None}
# {'encoding': None, 'confidence': 0.0, 'language': None}
# {'encoding': None, 'confidence': 0.0, 'language': None}
# {'encoding': None, 'confidence': 0.0, 'language': None}
# {'encoding': None, 'confidence': 0.0, 'language': None}
# {'encoding': None, 'confidence': 0.0, 'language': None}
# {'encoding': None, 'confidence': 0.0, 'language': None}
# {'encoding': None, 'confidence': 0.0, 'language': None}
# {'encoding': None, 'confidence': 0.0, 'language': None}
# {'encoding': None, 'confidence': 0.0, 'language': None}
# {'encoding': None, 'confidence': 0.0, 'language': None}
# {'encoding': None, 'confidence': 0.0, 'language': None}
# {'encoding': None, 'confidence': 0.0, 'language': None}
# {'encoding': None, 'confidence': 0.0, 'language': None}
# {'encoding': None, 'confidence': 0.0, 'language': None}
# {'encoding': None, 'confidence': 0.0, 'language': None}
# {'encoding': None, 'confidence': 0.0, 'language': None}
# {'encoding': None, 'confidence': 0.0, 'language': None}
# {'encoding': None, 'confidence': 0.0, 'language': None}
# {'encoding': None, 'confidence': 0.0, 'language': None}
# {'encoding': None, 'confidence': 0.0, 'language': None}
# {'encoding': None, 'confidence': 0.0, 'language': None}
# {'encoding': None, 'confidence': 0.0, 'language': None}
# {'encoding': None, 'confidence': 0.0, 'language': None}
# {'encoding': None, 'confidence': 0.0, 'language': None}
# {'encoding': None, 'confidence': 0.0, 'language': None}
# {'encoding': None, 'confidence': 0.0, 'language': None}
# {'encoding': None, 'confidence': 0.0, 'language': None}
# {'encoding': None, 'confidence': 0.0, 'language': None}
# {'encoding': None, 'confidence': 0.0, 'language': None}
# {'encoding': None, 'confidence': 0.0, 'language': None}
# {'encoding': None, 'confidence': 0.0, 'language': None}
# {'encoding': None, 'confidence': 0.0, 'language': None}
# {'encoding': None, 'confidence': 0.0, 'language': None}
# {'encoding': 'Windows-1252', 'confidence': 0.73, 'language': ''}
# {'encoding': None, 'confidence': 0.0, 'language': None}
# {'encoding': None, 'confidence': 0.0, 'language': None}
# {'encoding': None, 'confidence': 0.0, 'language': None}
# {'encoding': None, 'confidence': 0.0, 'language': None}
# {'encoding': None, 'confidence': 0.0, 'language': None}
# {'encoding': None, 'confidence': 0.0, 'language': None}
# {'encoding': 'Windows-1252', 'confidence': 0.73, 'language': ''}
# {'encoding': None, 'confidence': 0.0, 'language': None}
# {'encoding': None, 'confidence': 0.0, 'language': None}
# {'encoding': None, 'confidence': 0.0, 'language': None}
# {'encoding': None, 'confidence': 0.0, 'language': None}
# {'encoding': None, 'confidence': 0.0, 'language': None}
# {'encoding': 'Windows-1252', 'confidence': 0.73, 'language': ''}
# {'encoding': None, 'confidence': 0.0, 'language': None}
# {'encoding': None, 'confidence': 0.0, 'language': None}
# {'encoding': None, 'confidence': 0.0, 'language': None}
# {'encoding': None, 'confidence': 0.0, 'language': None}
# {'encoding': None, 'confidence': 0.0, 'language': None}
# {'encoding': None, 'confidence': 0.0, 'language': None}
# {'encoding': None, 'confidence': 0.0, 'language': None}
# {'encoding': None, 'confidence': 0.0, 'language': None}
# {'encoding': None, 'confidence': 0.0, 'language': None}
# {'encoding': 'MacCyrillic', 'confidence': 0.39007985958685376, 'language': 'Russian'}
# {'encoding': None, 'confidence': 0.0, 'language': None}
# {'encoding': None, 'confidence': 0.0, 'language': None}
# {'encoding': None, 'confidence': 0.0, 'language': None}
# {'encoding': None, 'confidence': 0.0, 'language': None}
# {'encoding': None, 'confidence': 0.0, 'language': None}
# {'encoding': None, 'confidence': 0.0, 'language': None}
# {'encoding': None, 'confidence': 0.0, 'language': None}
# {'encoding': None, 'confidence': 0.0, 'language': None}
# {'encoding': None, 'confidence': 0.0, 'language': None}
# {'encoding': None, 'confidence': 0.0, 'language': None}
# {'encoding': None, 'confidence': 0.0, 'language': None}
# {'encoding': None, 'confidence': 0.0, 'language': None}
# {'encoding': None, 'confidence': 0.0, 'language': None}
# {'encoding': 'windows-1253', 'confidence': 0.22696921819983198, 'language': 'Greek'}
# {'encoding': None, 'confidence': 0.0, 'language': None}
# {'encoding': None, 'confidence': 0.0, 'language': None}
# {'encoding': None, 'confidence': 0.0, 'language': None}
# {'encoding': None, 'confidence': 0.0, 'language': None}
# {'encoding': None, 'confidence': 0.0, 'language': None}
# {'encoding': None, 'confidence': 0.0, 'language': None}
# {'encoding': None, 'confidence': 0.0, 'language': None}
# {'encoding': None, 'confidence': 0.0, 'language': None}
# {'encoding': None, 'confidence': 0.0, 'language': None}
# {'encoding': None, 'confidence': 0.0, 'language': None}
# {'encoding': None, 'confidence': 0.0, 'language': None}
# {'encoding': None, 'confidence': 0.0, 'language': None}
# {'encoding': None, 'confidence': 0.0, 'language': None}
# {'encoding': None, 'confidence': 0.0, 'language': None}
# {'encoding': None, 'confidence': 0.0, 'language': None}
# {'encoding': 'Windows-1252', 'confidence': 0.219, 'language': ''}
# {'encoding': 'windows-1255', 'confidence': 0.31004421299376, 'language': 'Hebrew'}
# {'encoding': None, 'confidence': 0.0, 'language': None}
# {'encoding': None, 'confidence': 0.0, 'language': None}
# {'encoding': None, 'confidence': 0.0, 'language': None}
# {'encoding': 'Windows-1253', 'confidence': 0.45219920867399477, 'language': 'Greek'}
# {'encoding': None, 'confidence': 0.0, 'language': None}
# {'encoding': None, 'confidence': 0.0, 'language': None}
# {'encoding': None, 'confidence': 0.0, 'language': None}
# {'encoding': None, 'confidence': 0.0, 'language': None}
# {'encoding': 'Windows-1252', 'confidence': 0.73, 'language': ''}
# {'encoding': None, 'confidence': 0.0, 'language': None}
# {'encoding': None, 'confidence': 0.0, 'language': None}
# {'encoding': None, 'confidence': 0.0, 'language': None}
# {'encoding': None, 'confidence': 0.0, 'language': None}
# {'encoding': None, 'confidence': 0.0, 'language': None}
# {'encoding': None, 'confidence': 0.0, 'language': None}
# {'encoding': None, 'confidence': 0.0, 'language': None}
# {'encoding': None, 'confidence': 0.0, 'language': None}
# {'encoding': None, 'confidence': 0.0, 'language': None}
# {'encoding': None, 'confidence': 0.0, 'language': None}
# {'encoding': None, 'confidence': 0.0, 'language': None}
# {'encoding': None, 'confidence': 0.0, 'language': None}
# {'encoding': 'ISO-8859-1', 'confidence': 0.73, 'language': ''}
# {'encoding': None, 'confidence': 0.0, 'language': None}
# {'encoding': None, 'confidence': 0.0, 'language': None}
# {'encoding': None, 'confidence': 0.0, 'language': None}
# {'encoding': None, 'confidence': 0.0, 'language': None}
# {'encoding': None, 'confidence': 0.0, 'language': None}
# {'encoding': None, 'confidence': 0.0, 'language': None}
# {'encoding': None, 'confidence': 0.0, 'language': None}
# {'encoding': None, 'confidence': 0.0, 'language': None}
# {'encoding': None, 'confidence': 0.0, 'language': None}
# {'encoding': None, 'confidence': 0.0, 'language': None}
# {'encoding': None, 'confidence': 0.0, 'language': None}
# {'encoding': None, 'confidence': 0.0, 'language': None}
# {'encoding': None, 'confidence': 0.0, 'language': None}
# {'encoding': None, 'confidence': 0.0, 'language': None}
# {'encoding': None, 'confidence': 0.0, 'language': None}
# {'encoding': None, 'confidence': 0.0, 'language': None}
# {'encoding': 'windows-1253', 'confidence': 0.22118439554706265, 'language': 'Greek'}
# {'encoding': None, 'confidence': 0.0, 'language': None}
# {'encoding': None, 'confidence': 0.0, 'language': None}
# {'encoding': None, 'confidence': 0.0, 'language': None}
# {'encoding': None, 'confidence': 0.0, 'language': None}
# {'encoding': None, 'confidence': 0.0, 'language': None}
# {'encoding': None, 'confidence': 0.0, 'language': None}
# {'encoding': None, 'confidence': 0.0, 'language': None}
# {'encoding': 'KOI8-R', 'confidence': 0.31506450197399727, 'language': 'Russian'}
# {'encoding': None, 'confidence': 0.0, 'language': None}
# {'encoding': None, 'confidence': 0.0, 'language': None}
# {'encoding': None, 'confidence': 0.0, 'language': None}
# {'encoding': None, 'confidence': 0.0, 'language': None}
# {'encoding': None, 'confidence': 0.0, 'language': None}
# {'encoding': None, 'confidence': 0.0, 'language': None}
# {'encoding': None, 'confidence': 0.0, 'language': None}
# {'encoding': None, 'confidence': 0.0, 'language': None}
# {'encoding': None, 'confidence': 0.0, 'language': None}
# {'encoding': None, 'confidence': 0.0, 'language': None}
# {'encoding': None, 'confidence': 0.0, 'language': None}
# {'encoding': None, 'confidence': 0.0, 'language': None}
# {'encoding': None, 'confidence': 0.0, 'language': None}
# {'encoding': None, 'confidence': 0.0, 'language': None}
# {'encoding': None, 'confidence': 0.0, 'language': None}
# {'encoding': None, 'confidence': 0.0, 'language': None}
# {'encoding': None, 'confidence': 0.0, 'language': None}
# {'encoding': None, 'confidence': 0.0, 'language': None}
# {'encoding': None, 'confidence': 0.0, 'language': None}
# {'encoding': None, 'confidence': 0.0, 'language': None}
# {'encoding': None, 'confidence': 0.0, 'language': None}
# {'encoding': None, 'confidence': 0.0, 'language': None}
# {'encoding': None, 'confidence': 0.0, 'language': None}
# {'encoding': None, 'confidence': 0.0, 'language': None}
# {'encoding': None, 'confidence': 0.0, 'language': None}
# {'encoding': None, 'confidence': 0.0, 'language': None}
# {'encoding': None, 'confidence': 0.0, 'language': None}
# {'encoding': None, 'confidence': 0.0, 'language': None}
# {'encoding': None, 'confidence': 0.0, 'language': None}
# {'encoding': None, 'confidence': 0.0, 'language': None}
# {'encoding': None, 'confidence': 0.0, 'language': None}
# {'encoding': 'Windows-1252', 'confidence': 0.73, 'language': ''}
# {'encoding': None, 'confidence': 0.0, 'language': None}
# {'encoding': None, 'confidence': 0.0, 'language': None}
# {'encoding': None, 'confidence': 0.0, 'language': None}
# {'encoding': None, 'confidence': 0.0, 'language': None}
# {'encoding': None, 'confidence': 0.0, 'language': None}
# {'encoding': None, 'confidence': 0.0, 'language': None}
# {'encoding': None, 'confidence': 0.0, 'language': None}
# {'encoding': None, 'confidence': 0.0, 'language': None}
# {'encoding': None, 'confidence': 0.0, 'language': None}
# {'encoding': None, 'confidence': 0.0, 'language': None}
# {'encoding': 'Windows-1251', 'confidence': 0.22771526273139162, 'language': 'Russian'}
# {'encoding': None, 'confidence': 0.0, 'language': None}
# {'encoding': None, 'confidence': 0.0, 'language': None}
# {'encoding': None, 'confidence': 0.0, 'language': None}
# {'encoding': None, 'confidence': 0.0, 'language': None}
# {'encoding': None, 'confidence': 0.0, 'language': None}
# {'encoding': None, 'confidence': 0.0, 'language': None}
# {'encoding': None, 'confidence': 0.0, 'language': None}
# {'encoding': None, 'confidence': 0.0, 'language': None}
# {'encoding': None, 'confidence': 0.0, 'language': None}
# {'encoding': None, 'confidence': 0.0, 'language': None}
# {'encoding': None, 'confidence': 0.0, 'language': None}
# {'encoding': None, 'confidence': 0.0, 'language': None}
# {'encoding': None, 'confidence': 0.0, 'language': None}
# {'encoding': None, 'confidence': 0.0, 'language': None}
# {'encoding': None, 'confidence': 0.0, 'language': None}
# {'encoding': None, 'confidence': 0.0, 'language': None}
# {'encoding': None, 'confidence': 0.0, 'language': None}
# {'encoding': 'Windows-1252', 'confidence': 0.73, 'language': ''}
# {'encoding': None, 'confidence': 0.0, 'language': None}
# {'encoding': None, 'confidence': 0.0, 'language': None}
# {'encoding': None, 'confidence': 0.0, 'language': None}
# {'encoding': None, 'confidence': 0.0, 'language': None}
# {'encoding': None, 'confidence': 0.0, 'language': None}
# {'encoding': None, 'confidence': 0.0, 'language': None}
# {'encoding': None, 'confidence': 0.0, 'language': None}
# {'encoding': None, 'confidence': 0.0, 'language': None}
# {'encoding': None, 'confidence': 0.0, 'language': None}
# {'encoding': None, 'confidence': 0.0, 'language': None}
# {'encoding': None, 'confidence': 0.0, 'language': None}
# {'encoding': None, 'confidence': 0.0, 'language': None}
# {'encoding': None, 'confidence': 0.0, 'language': None}
# {'encoding': None, 'confidence': 0.0, 'language': None}
# {'encoding': None, 'confidence': 0.0, 'language': None}
# {'encoding': None, 'confidence': 0.0, 'language': None}
# {'encoding': None, 'confidence': 0.0, 'language': None}
# {'encoding': None, 'confidence': 0.0, 'language': None}
# {'encoding': None, 'confidence': 0.0, 'language': None}
# {'encoding': None, 'confidence': 0.0, 'language': None}
# {'encoding': None, 'confidence': 0.0, 'language': None}
# {'encoding': None, 'confidence': 0.0, 'language': None}
# {'encoding': None, 'confidence': 0.0, 'language': None}
# {'encoding': 'Windows-1253', 'confidence': 0.21479462412014752, 'language': 'Greek'}
# {'encoding': None, 'confidence': 0.0, 'language': None}
# {'encoding': None, 'confidence': 0.0, 'language': None}
# {'encoding': None, 'confidence': 0.0, 'language': None}
# {'encoding': None, 'confidence': 0.0, 'language': None}
# {'encoding': None, 'confidence': 0.0, 'language': None}
# {'encoding': None, 'confidence': 0.0, 'language': None}
# {'encoding': None, 'confidence': 0.0, 'language': None}
# {'encoding': None, 'confidence': 0.0, 'language': None}
# {'encoding': None, 'confidence': 0.0, 'language': None}
# {'encoding': None, 'confidence': 0.0, 'language': None}
# {'encoding': None, 'confidence': 0.0, 'language': None}
# {'encoding': None, 'confidence': 0.0, 'language': None}
# {'encoding': None, 'confidence': 0.0, 'language': None}
# {'encoding': None, 'confidence': 0.0, 'language': None}
# {'encoding': None, 'confidence': 0.0, 'language': None}
# {'encoding': None, 'confidence': 0.0, 'language': None}
# {'encoding': None, 'confidence': 0.0, 'language': None}
# {'encoding': None, 'confidence': 0.0, 'language': None}
# {'encoding': None, 'confidence': 0.0, 'language': None}
# {'encoding': None, 'confidence': 0.0, 'language': None}
# {'encoding': None, 'confidence': 0.0, 'language': None}
# {'encoding': None, 'confidence': 0.0, 'language': None}
# {'encoding': 'Windows-1252', 'confidence': 0.73, 'language': ''}
# {'encoding': 'Windows-1253', 'confidence': 0.22256679801923177, 'language': 'Greek'}
# {'encoding': None, 'confidence': 0.0, 'language': None}
# {'encoding': None, 'confidence': 0.0, 'language': None}
# {'encoding': None, 'confidence': 0.0, 'language': None}
# {'encoding': None, 'confidence': 0.0, 'language': None}
# {'encoding': None, 'confidence': 0.0, 'language': None}
# {'encoding': None, 'confidence': 0.0, 'language': None}
# {'encoding': None, 'confidence': 0.0, 'language': None}
# {'encoding': 'Windows-1253', 'confidence': 0.2560031003944712, 'language': 'Greek'}
# {'encoding': None, 'confidence': 0.0, 'language': None}
# {'encoding': None, 'confidence': 0.0, 'language': None}
# {'encoding': None, 'confidence': 0.0, 'language': None}
# {'encoding': None, 'confidence': 0.0, 'language': None}
# {'encoding': None, 'confidence': 0.0, 'language': None}
# {'encoding': None, 'confidence': 0.0, 'language': None}
# {'encoding': None, 'confidence': 0.0, 'language': None}
# {'encoding': None, 'confidence': 0.0, 'language': None}
# {'encoding': None, 'confidence': 0.0, 'language': None}
# {'encoding': None, 'confidence': 0.0, 'language': None}
# {'encoding': None, 'confidence': 0.0, 'language': None}
# {'encoding': None, 'confidence': 0.0, 'language': None}
# {'encoding': None, 'confidence': 0.0, 'language': None}
# {'encoding': None, 'confidence': 0.0, 'language': None}
# {'encoding': None, 'confidence': 0.0, 'language': None}
# {'encoding': None, 'confidence': 0.0, 'language': None}
# {'encoding': None, 'confidence': 0.0, 'language': None}
# {'encoding': None, 'confidence': 0.0, 'language': None}
# {'encoding': 'ascii', 'confidence': 1.0, 'language': ''}
# {'encoding': None, 'confidence': 0.0, 'language': None}
# {'encoding': None, 'confidence': 0.0, 'language': None}
# {'encoding': None, 'confidence': 0.0, 'language': None}
# {'encoding': None, 'confidence': 0.0, 'language': None}
# {'encoding': None, 'confidence': 0.0, 'language': None}
# {'encoding': None, 'confidence': 0.0, 'language': None}
# {'encoding': None, 'confidence': 0.0, 'language': None}
# {'encoding': None, 'confidence': 0.0, 'language': None}
# {'encoding': None, 'confidence': 0.0, 'language': None}
# {'encoding': None, 'confidence': 0.0, 'language': None}
# {'encoding': 'Windows-1252', 'confidence': 0.73, 'language': ''}
# {'encoding': None, 'confidence': 0.0, 'language': None}
# {'encoding': None, 'confidence': 0.0, 'language': None}
# {'encoding': None, 'confidence': 0.0, 'language': None}
# {'encoding': None, 'confidence': 0.0, 'language': None}
# {'encoding': 'KOI8-R', 'confidence': 0.2389239139969479, 'language': 'Russian'}
# {'encoding': None, 'confidence': 0.0, 'language': None}
# {'encoding': None, 'confidence': 0.0, 'language': None}
# {'encoding': None, 'confidence': 0.0, 'language': None}
# {'encoding': None, 'confidence': 0.0, 'language': None}
# {'encoding': None, 'confidence': 0.0, 'language': None}
# {'encoding': None, 'confidence': 0.0, 'language': None}
# {'encoding': None, 'confidence': 0.0, 'language': None}
# {'encoding': None, 'confidence': 0.0, 'language': None}
# {'encoding': 'Windows-1252', 'confidence': 0.40382978723404256, 'language': ''}
# {'encoding': None, 'confidence': 0.0, 'language': None}
# {'encoding': None, 'confidence': 0.0, 'language': None}
# {'encoding': None, 'confidence': 0.0, 'language': None}
# {'encoding': None, 'confidence': 0.0, 'language': None}
# {'encoding': None, 'confidence': 0.0, 'language': None}
# {'encoding': None, 'confidence': 0.0, 'language': None}
# {'encoding': None, 'confidence': 0.0, 'language': None}
# {'encoding': None, 'confidence': 0.0, 'language': None}
# {'encoding': None, 'confidence': 0.0, 'language': None}
# {'encoding': None, 'confidence': 0.0, 'language': None}
# {'encoding': None, 'confidence': 0.0, 'language': None}
# {'encoding': None, 'confidence': 0.0, 'language': None}
# {'encoding': None, 'confidence': 0.0, 'language': None}
# {'encoding': None, 'confidence': 0.0, 'language': None}
# {'encoding': None, 'confidence': 0.0, 'language': None}
# {'encoding': None, 'confidence': 0.0, 'language': None}
# {'encoding': None, 'confidence': 0.0, 'language': None}
# {'encoding': None, 'confidence': 0.0, 'language': None}
# {'encoding': None, 'confidence': 0.0, 'language': None}
# {'encoding': None, 'confidence': 0.0, 'language': None}
# {'encoding': None, 'confidence': 0.0, 'language': None}
# {'encoding': None, 'confidence': 0.0, 'language': None}
# {'encoding': None, 'confidence': 0.0, 'language': None}
# {'encoding': None, 'confidence': 0.0, 'language': None}
# {'encoding': None, 'confidence': 0.0, 'language': None}
# {'encoding': None, 'confidence': 0.0, 'language': None}
# {'encoding': None, 'confidence': 0.0, 'language': None}
# {'encoding': None, 'confidence': 0.0, 'language': None}
# {'encoding': 'IBM855', 'confidence': 0.4311408974381015, 'language': 'Russian'}
# {'encoding': None, 'confidence': 0.0, 'language': None}
# {'encoding': None, 'confidence': 0.0, 'language': None}
# {'encoding': None, 'confidence': 0.0, 'language': None}
# {'encoding': None, 'confidence': 0.0, 'language': None}
# {'encoding': None, 'confidence': 0.0, 'language': None}
# {'encoding': None, 'confidence': 0.0, 'language': None}
# {'encoding': 'Windows-1252', 'confidence': 0.73, 'language': ''}
# {'encoding': None, 'confidence': 0.0, 'language': None}
# {'encoding': None, 'confidence': 0.0, 'language': None}
# {'encoding': None, 'confidence': 0.0, 'language': None}
# {'encoding': None, 'confidence': 0.0, 'language': None}
# {'encoding': None, 'confidence': 0.0, 'language': None}
# {'encoding': None, 'confidence': 0.0, 'language': None}
# {'encoding': None, 'confidence': 0.0, 'language': None}
# {'encoding': None, 'confidence': 0.0, 'language': None}
# {'encoding': 'ascii', 'confidence': 1.0, 'language': ''}
# {'encoding': 'IBM855', 'confidence': 0.20722992540551605, 'language': 'Russian'}
# {'encoding': None, 'confidence': 0.0, 'language': None}
# {'encoding': None, 'confidence': 0.0, 'language': None}
# {'encoding': None, 'confidence': 0.0, 'language': None}
# {'encoding': None, 'confidence': 0.0, 'language': None}
# {'encoding': 'windows-1251', 'confidence': 0.21720355817904355, 'language': 'Russian'}
# {'encoding': None, 'confidence': 0.0, 'language': None}
# {'encoding': 'Windows-1251', 'confidence': 0.25598990785387277, 'language': 'Russian'}
# {'encoding': None, 'confidence': 0.0, 'language': None}
# {'encoding': None, 'confidence': 0.0, 'language': None}
# {'encoding': None, 'confidence': 0.0, 'language': None}
# {'encoding': None, 'confidence': 0.0, 'language': None}
# {'encoding': None, 'confidence': 0.0, 'language': None}
# {'encoding': None, 'confidence': 0.0, 'language': None}
# {'encoding': None, 'confidence': 0.0, 'language': None}
# {'encoding': None, 'confidence': 0.0, 'language': None}
# {'encoding': None, 'confidence': 0.0, 'language': None}
# {'encoding': None, 'confidence': 0.0, 'language': None}
# {'encoding': None, 'confidence': 0.0, 'language': None}
# {'encoding': None, 'confidence': 0.0, 'language': None}
# {'encoding': None, 'confidence': 0.0, 'language': None}
# {'encoding': None, 'confidence': 0.0, 'language': None}
# {'encoding': None, 'confidence': 0.0, 'language': None}
# {'encoding': None, 'confidence': 0.0, 'language': None}
# {'encoding': None, 'confidence': 0.0, 'language': None}
# {'encoding': None, 'confidence': 0.0, 'language': None}
# {'encoding': None, 'confidence': 0.0, 'language': None}
# {'encoding': None, 'confidence': 0.0, 'language': None}
# {'encoding': None, 'confidence': 0.0, 'language': None}
# {'encoding': None, 'confidence': 0.0, 'language': None}
# {'encoding': None, 'confidence': 0.0, 'language': None}
# {'encoding': None, 'confidence': 0.0, 'language': None}
# {'encoding': None, 'confidence': 0.0, 'language': None}
# {'encoding': None, 'confidence': 0.0, 'language': None}
# {'encoding': None, 'confidence': 0.0, 'language': None}
# {'encoding': None, 'confidence': 0.0, 'language': None}
# {'encoding': None, 'confidence': 0.0, 'language': None}
# {'encoding': None, 'confidence': 0.0, 'language': None}
# {'encoding': None, 'confidence': 0.0, 'language': None}
# {'encoding': 'ascii', 'confidence': 1.0, 'language': ''}
# {'encoding': 'IBM866', 'confidence': 0.24650880015558116, 'language': 'Russian'}
# {'encoding': None, 'confidence': 0.0, 'language': None}
# {'encoding': None, 'confidence': 0.0, 'language': None}
# {'encoding': None, 'confidence': 0.0, 'language': None}
# {'encoding': None, 'confidence': 0.0, 'language': None}
# {'encoding': None, 'confidence': 0.0, 'language': None}
# {'encoding': None, 'confidence': 0.0, 'language': None}
# {'encoding': None, 'confidence': 0.0, 'language': None}
# {'encoding': None, 'confidence': 0.0, 'language': None}
# {'encoding': None, 'confidence': 0.0, 'language': None}
# {'encoding': None, 'confidence': 0.0, 'language': None}
# {'encoding': None, 'confidence': 0.0, 'language': None}
# {'encoding': None, 'confidence': 0.0, 'language': None}
# {'encoding': None, 'confidence': 0.0, 'language': None}
# {'encoding': None, 'confidence': 0.0, 'language': None}
# {'encoding': None, 'confidence': 0.0, 'language': None}
# {'encoding': None, 'confidence': 0.0, 'language': None}
# {'encoding': None, 'confidence': 0.0, 'language': None}
# {'encoding': None, 'confidence': 0.0, 'language': None}
# {'encoding': None, 'confidence': 0.0, 'language': None}
# {'encoding': None, 'confidence': 0.0, 'language': None}
# {'encoding': None, 'confidence': 0.0, 'language': None}
# {'encoding': None, 'confidence': 0.0, 'language': None}
# {'encoding': None, 'confidence': 0.0, 'language': None}
# {'encoding': None, 'confidence': 0.0, 'language': None}
# {'encoding': 'TIS-620', 'confidence': 0.2065640291318716, 'language': 'Thai'}
# {'encoding': None, 'confidence': 0.0, 'language': None}
# {'encoding': None, 'confidence': 0.0, 'language': None}
# {'encoding': None, 'confidence': 0.0, 'language': None}
# {'encoding': None, 'confidence': 0.0, 'language': None}
# {'encoding': None, 'confidence': 0.0, 'language': None}
# {'encoding': None, 'confidence': 0.0, 'language': None}
# {'encoding': None, 'confidence': 0.0, 'language': None}
# {'encoding': None, 'confidence': 0.0, 'language': None}
# {'encoding': None, 'confidence': 0.0, 'language': None}
# {'encoding': None, 'confidence': 0.0, 'language': None}
# {'encoding': None, 'confidence': 0.0, 'language': None}
# {'encoding': None, 'confidence': 0.0, 'language': None}
# {'encoding': None, 'confidence': 0.0, 'language': None}
# {'encoding': 'KOI8-R', 'confidence': 0.38398486178080915, 'language': 'Russian'}
# {'encoding': None, 'confidence': 0.0, 'language': None}
# {'encoding': 'Windows-1252', 'confidence': 0.73, 'language': ''}
# {'encoding': None, 'confidence': 0.0, 'language': None}
# {'encoding': None, 'confidence': 0.0, 'language': None}
# {'encoding': None, 'confidence': 0.0, 'language': None}
# {'encoding': None, 'confidence': 0.0, 'language': None}
# {'encoding': None, 'confidence': 0.0, 'language': None}
# {'encoding': None, 'confidence': 0.0, 'language': None}
# {'encoding': None, 'confidence': 0.0, 'language': None}
# {'encoding': None, 'confidence': 0.0, 'language': None}
# {'encoding': None, 'confidence': 0.0, 'language': None}
# {'encoding': None, 'confidence': 0.0, 'language': None}
# {'encoding': None, 'confidence': 0.0, 'language': None}
# ...
# {'encoding': None, 'confidence': 0.0, 'language': None}
# {'encoding': 'ISO-8859-1', 'confidence': 0.73, 'language': ''}
# {'encoding': None, 'confidence': 0.0, 'language': None}
# {'encoding': None, 'confidence': 0.0, 'language': None}
# {'encoding': None, 'confidence': 0.0, 'language': None}
# {'encoding': None, 'confidence': 0.0, 'language': None}
# {'encoding': None, 'confidence': 0.0, 'language': None}
# {'encoding': None, 'confidence': 0.0, 'language': None}
# {'encoding': None, 'confidence': 0.0, 'language': None}
# {'encoding': 'windows-1253', 'confidence': 0.3662813590259358, 'language': 'Greek'}
# {'encoding': None, 'confidence': 0.0, 'language': None}
# {'encoding': None, 'confidence': 0.0, 'language': None}
# {'encoding': None, 'confidence': 0.0, 'language': None}
# {'encoding': None, 'confidence': 0.0, 'language': None}
# {'encoding': None, 'confidence': 0.0, 'language': None}
# {'encoding': None, 'confidence': 0.0, 'language': None}
# {'encoding': None, 'confidence': 0.0, 'language': None}
# {'encoding': None, 'confidence': 0.0, 'language': None}
# {'encoding': None, 'confidence': 0.0, 'language': None}
# {'encoding': None, 'confidence': 0.0, 'language': None}
# {'encoding': None, 'confidence': 0.0, 'language': None}
# {'encoding': None, 'confidence': 0.0, 'language': None}
# {'encoding': None, 'confidence': 0.0, 'language': None}
# {'encoding': None, 'confidence': 0.0, 'language': None}
# {'encoding': None, 'confidence': 0.0, 'language': None}
# {'encoding': None, 'confidence': 0.0, 'language': None}
# {'encoding': None, 'confidence': 0.0, 'language': None}
# {'encoding': None, 'confidence': 0.0, 'language': None}
# {'encoding': None, 'confidence': 0.0, 'language': None}
# {'encoding': None, 'confidence': 0.0, 'language': None}
# {'encoding': 'Windows-1252', 'confidence': 0.3041666666666667, 'language': ''}
# {'encoding': None, 'confidence': 0.0, 'language': None}
# {'encoding': None, 'confidence': 0.0, 'language': None}
# {'encoding': None, 'confidence': 0.0, 'language': None}
# {'encoding': None, 'confidence': 0.0, 'language': None}
# {'encoding': None, 'confidence': 0.0, 'language': None}
# {'encoding': None, 'confidence': 0.0, 'language': None}
# {'encoding': None, 'confidence': 0.0, 'language': None}
# {'encoding': None, 'confidence': 0.0, 'language': None}
# {'encoding': None, 'confidence': 0.0, 'language': None}
# {'encoding': None, 'confidence': 0.0, 'language': None}
# {'encoding': None, 'confidence': 0.0, 'language': None}
# {'encoding': None, 'confidence': 0.0, 'language': None}
# {'encoding': None, 'confidence': 0.0, 'language': None}
# {'encoding': None, 'confidence': 0.0, 'language': None}
# {'encoding': None, 'confidence': 0.0, 'language': None}
# {'encoding': None, 'confidence': 0.0, 'language': None}
# {'encoding': None, 'confidence': 0.0, 'language': None}
# {'encoding': None, 'confidence': 0.0, 'language': None}
# {'encoding': None, 'confidence': 0.0, 'language': None}
# {'encoding': None, 'confidence': 0.0, 'language': None}
# {'encoding': None, 'confidence': 0.0, 'language': None}
# {'encoding': None, 'confidence': 0.0, 'language': None}
# {'encoding': None, 'confidence': 0.0, 'language': None}
# {'encoding': None, 'confidence': 0.0, 'language': None}
# {'encoding': None, 'confidence': 0.0, 'language': None}
# {'encoding': None, 'confidence': 0.0, 'language': None}
# {'encoding': None, 'confidence': 0.0, 'language': None}
# {'encoding': None, 'confidence': 0.0, 'language': None}
# {'encoding': None, 'confidence': 0.0, 'language': None}
# {'encoding': None, 'confidence': 0.0, 'language': None}
# {'encoding': None, 'confidence': 0.0, 'language': None}
# {'encoding': None, 'confidence': 0.0, 'language': None}
# {'encoding': None, 'confidence': 0.0, 'language': None}
# {'encoding': None, 'confidence': 0.0, 'language': None}
# {'encoding': None, 'confidence': 0.0, 'language': None}
# {'encoding': None, 'confidence': 0.0, 'language': None}
# {'encoding': None, 'confidence': 0.0, 'language': None}
# {'encoding': None, 'confidence': 0.0, 'language': None}
# {'encoding': None, 'confidence': 0.0, 'language': None}
# {'encoding': None, 'confidence': 0.0, 'language': None}
# {'encoding': None, 'confidence': 0.0, 'language': None}
# {'encoding': None, 'confidence': 0.0, 'language': None}
# {'encoding': 'Windows-1254', 'confidence': 0.2829152149579699, 'language': 'Turkish'}
# {'encoding': None, 'confidence': 0.0, 'language': None}
# {'encoding': None, 'confidence': 0.0, 'language': None}
# {'encoding': None, 'confidence': 0.0, 'language': None}
# {'encoding': None, 'confidence': 0.0, 'language': None}
# {'encoding': 'Windows-1252', 'confidence': 0.73, 'language': ''}
# {'encoding': None, 'confidence': 0.0, 'language': None}
# {'encoding': None, 'confidence': 0.0, 'language': None}
# {'encoding': None, 'confidence': 0.0, 'language': None}
# {'encoding': None, 'confidence': 0.0, 'language': None}
# {'encoding': None, 'confidence': 0.0, 'language': None}
# {'encoding': None, 'confidence': 0.0, 'language': None}
# {'encoding': None, 'confidence': 0.0, 'language': None}
# {'encoding': None, 'confidence': 0.0, 'language': None}
# {'encoding': None, 'confidence': 0.0, 'language': None}
# {'encoding': None, 'confidence': 0.0, 'language': None}
# {'encoding': 'windows-1253', 'confidence': 0.25436205487912206, 'language': 'Greek'}
# {'encoding': None, 'confidence': 0.0, 'language': None}
# {'encoding': None, 'confidence': 0.0, 'language': None}
# {'encoding': 'Windows-1251', 'confidence': 0.24867591048661924, 'language': 'Russian'}
# {'encoding': 'Windows-1254', 'confidence': 0.38171100430837207, 'language': 'Turkish'}
# {'encoding': None, 'confidence': 0.0, 'language': None}
# {'encoding': None, 'confidence': 0.0, 'language': None}
# {'encoding': None, 'confidence': 0.0, 'language': None}
# {'encoding': None, 'confidence': 0.0, 'language': None}
# {'encoding': None, 'confidence': 0.0, 'language': None}
# {'encoding': None, 'confidence': 0.0, 'language': None}
# {'encoding': None, 'confidence': 0.0, 'language': None}
# {'encoding': None, 'confidence': 0.0, 'language': None}
# {'encoding': None, 'confidence': 0.0, 'language': None}
# {'encoding': None, 'confidence': 0.0, 'language': None}
# {'encoding': None, 'confidence': 0.0, 'language': None}
# {'encoding': None, 'confidence': 0.0, 'language': None}
# {'encoding': None, 'confidence': 0.0, 'language': None}
# {'encoding': None, 'confidence': 0.0, 'language': None}
# {'encoding': 'ISO-8859-7', 'confidence': 0.5549717560999027, 'language': 'Greek'}
# {'encoding': None, 'confidence': 0.0, 'language': None}
# {'encoding': None, 'confidence': 0.0, 'language': None}
# {'encoding': None, 'confidence': 0.0, 'language': None}
# {'encoding': None, 'confidence': 0.0, 'language': None}
# {'encoding': None, 'confidence': 0.0, 'language': None}
# {'encoding': None, 'confidence': 0.0, 'language': None}
# {'encoding': None, 'confidence': 0.0, 'language': None}
# {'encoding': None, 'confidence': 0.0, 'language': None}
# {'encoding': None, 'confidence': 0.0, 'language': None}
# {'encoding': None, 'confidence': 0.0, 'language': None}
# {'encoding': None, 'confidence': 0.0, 'language': None}
# {'encoding': 'Windows-1252', 'confidence': 0.73, 'language': ''}
# {'encoding': 'windows-1253', 'confidence': 0.2089187833387453, 'language': 'Greek'}
# {'encoding': 'Windows-1251', 'confidence': 0.22399116937213867, 'language': 'Russian'}
# {'encoding': None, 'confidence': 0.0, 'language': None}
# {'encoding': None, 'confidence': 0.0, 'language': None}
# {'encoding': None, 'confidence': 0.0, 'language': None}
# {'encoding': None, 'confidence': 0.0, 'language': None}
# {'encoding': None, 'confidence': 0.0, 'language': None}
# {'encoding': 'Windows-1252', 'confidence': 0.73, 'language': ''}
# {'encoding': None, 'confidence': 0.0, 'language': None}
# {'encoding': None, 'confidence': 0.0, 'language': None}
# {'encoding': None, 'confidence': 0.0, 'language': None}
# {'encoding': None, 'confidence': 0.0, 'language': None}
# {'encoding': None, 'confidence': 0.0, 'language': None}
# {'encoding': None, 'confidence': 0.0, 'language': None}
# {'encoding': None, 'confidence': 0.0, 'language': None}
# {'encoding': None, 'confidence': 0.0, 'language': None}
# {'encoding': None, 'confidence': 0.0, 'language': None}
# {'encoding': None, 'confidence': 0.0, 'language': None}
# {'encoding': None, 'confidence': 0.0, 'language': None}
# {'encoding': 'windows-1251', 'confidence': 0.2321042467856141, 'language': 'Bulgarian'}
# {'encoding': None, 'confidence': 0.0, 'language': None}
# {'encoding': 'Windows-1253', 'confidence': 0.2050670830033232, 'language': 'Greek'}
# {'encoding': None, 'confidence': 0.0, 'language': None}
# {'encoding': 'Windows-1253', 'confidence': 0.2848855014646167, 'language': 'Greek'}
# {'encoding': 'Windows-1252', 'confidence': 0.73, 'language': ''}
# {'encoding': 'ISO-8859-1', 'confidence': 0.73, 'language': ''}
# {'encoding': None, 'confidence': 0.0, 'language': None}
# {'encoding': None, 'confidence': 0.0, 'language': None}
# {'encoding': None, 'confidence': 0.0, 'language': None}
# {'encoding': None, 'confidence': 0.0, 'language': None}
# {'encoding': None, 'confidence': 0.0, 'language': None}
# {'encoding': None, 'confidence': 0.0, 'language': None}
# {'encoding': None, 'confidence': 0.0, 'language': None}
# {'encoding': None, 'confidence': 0.0, 'language': None}
# {'encoding': 'IBM855', 'confidence': 0.5119798157077455, 'language': 'Russian'}
# {'encoding': None, 'confidence': 0.0, 'language': None}
# {'encoding': None, 'confidence': 0.0, 'language': None}
# {'encoding': None, 'confidence': 0.0, 'language': None}
# {'encoding': None, 'confidence': 0.0, 'language': None}
# {'encoding': None, 'confidence': 0.0, 'language': None}
# {'encoding': None, 'confidence': 0.0, 'language': None}
# {'encoding': None, 'confidence': 0.0, 'language': None}
# {'encoding': None, 'confidence': 0.0, 'language': None}
# {'encoding': None, 'confidence': 0.0, 'language': None}
# {'encoding': 'IBM855', 'confidence': 0.23223826691897734, 'language': 'Russian'}
# {'encoding': None, 'confidence': 0.0, 'language': None}
# {'encoding': None, 'confidence': 0.0, 'language': None}
# {'encoding': None, 'confidence': 0.0, 'language': None}
# {'encoding': None, 'confidence': 0.0, 'language': None}
# {'encoding': 'Windows-1252', 'confidence': 0.2509375, 'language': ''}
# {'encoding': None, 'confidence': 0.0, 'language': None}
# {'encoding': None, 'confidence': 0.0, 'language': None}
# {'encoding': None, 'confidence': 0.0, 'language': None}
# {'encoding': None, 'confidence': 0.0, 'language': None}
# {'encoding': None, 'confidence': 0.0, 'language': None}
# {'encoding': None, 'confidence': 0.0, 'language': None}
# {'encoding': None, 'confidence': 0.0, 'language': None}
# {'encoding': None, 'confidence': 0.0, 'language': None}
# {'encoding': 'KOI8-R', 'confidence': 0.45509316951799605, 'language': 'Russian'}
# {'encoding': None, 'confidence': 0.0, 'language': None}
# {'encoding': None, 'confidence': 0.0, 'language': None}
# {'encoding': None, 'confidence': 0.0, 'language': None}
# {'encoding': 'ISO-8859-1', 'confidence': 0.73, 'language': ''}
# {'encoding': None, 'confidence': 0.0, 'language': None}
# {'encoding': None, 'confidence': 0.0, 'language': None}
# {'encoding': None, 'confidence': 0.0, 'language': None}
# {'encoding': None, 'confidence': 0.0, 'language': None}
# {'encoding': None, 'confidence': 0.0, 'language': None}
# {'encoding': None, 'confidence': 0.0, 'language': None}
# {'encoding': None, 'confidence': 0.0, 'language': None}
# {'encoding': None, 'confidence': 0.0, 'language': None}
# {'encoding': None, 'confidence': 0.0, 'language': None}
# {'encoding': 'Windows-1252', 'confidence': 0.73, 'language': ''}
# {'encoding': None, 'confidence': 0.0, 'language': None}
# {'encoding': None, 'confidence': 0.0, 'language': None}
# {'encoding': None, 'confidence': 0.0, 'language': None}
# {'encoding': None, 'confidence': 0.0, 'language': None}
# {'encoding': 'Windows-1252', 'confidence': 0.410625, 'language': ''}
# {'encoding': None, 'confidence': 0.0, 'language': None}
# {'encoding': None, 'confidence': 0.0, 'language': None}
# {'encoding': None, 'confidence': 0.0, 'language': None}
# {'encoding': None, 'confidence': 0.0, 'language': None}
# {'encoding': None, 'confidence': 0.0, 'language': None}
# {'encoding': None, 'confidence': 0.0, 'language': None}
# {'encoding': None, 'confidence': 0.0, 'language': None}
# {'encoding': None, 'confidence': 0.0, 'language': None}
# {'encoding': None, 'confidence': 0.0, 'language': None}
# {'encoding': None, 'confidence': 0.0, 'language': None}
# {'encoding': None, 'confidence': 0.0, 'language': None}
# {'encoding': None, 'confidence': 0.0, 'language': None}
# {'encoding': None, 'confidence': 0.0, 'language': None}
# {'encoding': None, 'confidence': 0.0, 'language': None}
# {'encoding': None, 'confidence': 0.0, 'language': None}
# {'encoding': None, 'confidence': 0.0, 'language': None}
# {'encoding': None, 'confidence': 0.0, 'language': None}
# {'encoding': None, 'confidence': 0.0, 'language': None}
# {'encoding': None, 'confidence': 0.0, 'language': None}
# {'encoding': None, 'confidence': 0.0, 'language': None}
# {'encoding': None, 'confidence': 0.0, 'language': None}
# {'encoding': None, 'confidence': 0.0, 'language': None}
# {'encoding': None, 'confidence': 0.0, 'language': None}
# {'encoding': None, 'confidence': 0.0, 'language': None}
# {'encoding': None, 'confidence': 0.0, 'language': None}
# {'encoding': None, 'confidence': 0.0, 'language': None}
# {'encoding': None, 'confidence': 0.0, 'language': None}
# {'encoding': 'Windows-1253', 'confidence': 0.35610687683077086, 'language': 'Greek'}
# {'encoding': None, 'confidence': 0.0, 'language': None}
# {'encoding': None, 'confidence': 0.0, 'language': None}
# {'encoding': 'Windows-1252', 'confidence': 0.27114285714285713, 'language': ''}
# {'encoding': None, 'confidence': 0.0, 'language': None}
# {'encoding': None, 'confidence': 0.0, 'language': None}
# {'encoding': None, 'confidence': 0.0, 'language': None}
# {'encoding': None, 'confidence': 0.0, 'language': None}
# {'encoding': None, 'confidence': 0.0, 'language': None}
# {'encoding': None, 'confidence': 0.0, 'language': None}
# {'encoding': None, 'confidence': 0.0, 'language': None}
# {'encoding': None, 'confidence': 0.0, 'language': None}
# {'encoding': None, 'confidence': 0.0, 'language': None}
# {'encoding': None, 'confidence': 0.0, 'language': None}
# {'encoding': None, 'confidence': 0.0, 'language': None}
# {'encoding': None, 'confidence': 0.0, 'language': None}
# {'encoding': None, 'confidence': 0.0, 'language': None}
# {'encoding': None, 'confidence': 0.0, 'language': None}
# {'encoding': None, 'confidence': 0.0, 'language': None}
# {'encoding': 'ascii', 'confidence': 1.0, 'language': ''}
# {'encoding': None, 'confidence': 0.0, 'language': None}
# {'encoding': None, 'confidence': 0.0, 'language': None}
# {'encoding': None, 'confidence': 0.0, 'language': None}
# {'encoding': None, 'confidence': 0.0, 'language': None}
# {'encoding': None, 'confidence': 0.0, 'language': None}
# {'encoding': None, 'confidence': 0.0, 'language': None}
# {'encoding': None, 'confidence': 0.0, 'language': None}
# {'encoding': None, 'confidence': 0.0, 'language': None}
# {'encoding': None, 'confidence': 0.0, 'language': None}
# {'encoding': None, 'confidence': 0.0, 'language': None}
# {'encoding': None, 'confidence': 0.0, 'language': None}
# {'encoding': None, 'confidence': 0.0, 'language': None}
# {'encoding': None, 'confidence': 0.0, 'language': None}
# {'encoding': None, 'confidence': 0.0, 'language': None}
# {'encoding': None, 'confidence': 0.0, 'language': None}
# {'encoding': None, 'confidence': 0.0, 'language': None}
# {'encoding': None, 'confidence': 0.0, 'language': None}
# {'encoding': None, 'confidence': 0.0, 'language': None}
# {'encoding': 'ascii', 'confidence': 1.0, 'language': ''}
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <timed exec> in <module>
#
# <ipython-input-34-2d51564792ef> in taq_data_extract_juan(ticker, year, month, day)
#      24             print(chardet.detect(line))
#      25             list_line = line.split()
# ---> 26             if (list_line[0] == date
#      27                     and list_line[1] >= '34800'
#      28                     and list_line[1] <= '57000'):
#
# IndexError: list index out of range

# %%
# %%time
w, z = taq_data_extract_droopy(ticker, year, month, day, chunksize)
# Out:
# ---------------------------------------------------------------------------
# UnicodeDecodeError                        Traceback (most recent call last)
# pandas/_libs/parsers.pyx in pandas._libs.parsers.TextReader._convert_tokens()
#
# pandas/_libs/parsers.pyx in pandas._libs.parsers.TextReader._convert_with_dtype()
#
# pandas/_libs/parsers.pyx in pandas._libs.parsers.TextReader._string_convert()
#
# pandas/_libs/parsers.pyx in pandas._libs.parsers._string_box_utf8()
#
# UnicodeDecodeError: 'utf-8' codec can't decode byte 0xad in position 1: invalid start byte
#
# During handling of the above exception, another exception occurred:
#
# UnicodeDecodeError                        Traceback (most recent call last)
# <timed exec> in <module>
#
# <ipython-input-3-a21e33aece60> in taq_data_extract_droopy(ticker, year, month, day, chunksize)
#      22
#      23     for chunk in pd.read_csv(quotes_filename, chunksize=chunksize, sep="\s+",
# ---> 24                              names = ['Date', 'Time', 'Bid', 'Ask'], usecols=range(4)
#      25                         ):
#      26
#
# ~/.pyenv/versions/3.6.5/lib/python3.6/site-packages/pandas/io/parsers.py in __next__(self)
#    1108     def __next__(self):
#    1109         try:
# -> 1110             return self.get_chunk()
#    1111         except StopIteration:
#    1112             self.close()
#
# ~/.pyenv/versions/3.6.5/lib/python3.6/site-packages/pandas/io/parsers.py in get_chunk(self, size)
#    1166                 raise StopIteration
#    1167             size = min(size, self.nrows - self._currow)
# -> 1168         return self.read(nrows=size)
#    1169
#    1170
#
# ~/.pyenv/versions/3.6.5/lib/python3.6/site-packages/pandas/io/parsers.py in read(self, nrows)
#    1132     def read(self, nrows=None):
#    1133         nrows = _validate_integer('nrows', nrows)
# -> 1134         ret = self._engine.read(nrows)
#    1135
#    1136         # May alter columns / col_dict
#
# ~/.pyenv/versions/3.6.5/lib/python3.6/site-packages/pandas/io/parsers.py in read(self, nrows)
#    1988     def read(self, nrows=None):
#    1989         try:
# -> 1990             data = self._reader.read(nrows)
#    1991         except StopIteration:
#    1992             if self._first_chunk:
#
# pandas/_libs/parsers.pyx in pandas._libs.parsers.TextReader.read()
#
# pandas/_libs/parsers.pyx in pandas._libs.parsers.TextReader._read_low_memory()
#
# pandas/_libs/parsers.pyx in pandas._libs.parsers.TextReader._read_rows()
#
# pandas/_libs/parsers.pyx in pandas._libs.parsers.TextReader._convert_column_data()
#
# pandas/_libs/parsers.pyx in pandas._libs.parsers.TextReader._convert_tokens()
#
# pandas/_libs/parsers.pyx in pandas._libs.parsers.TextReader._convert_with_dtype()
#
# pandas/_libs/parsers.pyx in pandas._libs.parsers.TextReader._string_convert()
#
# pandas/_libs/parsers.pyx in pandas._libs.parsers._string_box_utf8()
#
# UnicodeDecodeError: 'utf-8' codec can't decode byte 0xad in position 1: invalid start byte

# %%
import chardet
quotes_filename = '../TAQ_2008/Data/AAPL_2008_NASDAQ.quotes'
x = open(quotes_filename, 'rb')
chardet.detect(x)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-29-0cf2267ec50c> in <module>
#       2 quotes_filename = '../TAQ_2008/Data/AAPL_2008_NASDAQ.quotes'
#       3 x = open(quotes_filename, 'rb')
# ----> 4 chardet.detect(x)
#
# ~/.pyenv/versions/3.6.5/lib/python3.6/site-packages/chardet/__init__.py in detect(byte_str)
#      32         if not isinstance(byte_str, bytes):
#      33             raise TypeError('Expected object of type bytes or bytearray, got: '
# ---> 34                             '{0}'.format(type(byte_str)))
#      35         else:
#      36             byte_str = bytearray(byte_str)
#
# TypeError: Expected object of type bytes or bytearray, got: <class '_io.BufferedReader'>
